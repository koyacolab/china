# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# !ls
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# gdrive	sample_data

# %%
import os

home_dir = '/content/gdrive/My Drive/AYield/China'
os.chdir(home_dir)
# !pwd
# !ls
# !pip3 install --upgrade IPython
# !pip install fire
# !pip install geopandas
# !pip install geojson
# !pip install tqdm

from tqdm import tqdm
import geojson

from glob import glob

# sudo apt-get update & apt-get upgrade

# !pip install --upgrade google-api-python-client
# !gcloud init
# Out:
# /content/gdrive/My Drive/AYield/China
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fire in /usr/local/lib/python3.7/dist-packages (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire) (1.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.4)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (3.2.1)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.21)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2022.6.15)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2022.2.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geojson in /usr/local/lib/python3.7/dist-packages (2.5.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.0)

# %%
# !git clone https://github.com/gabrieltseng/pycrop-yield-prediction.git

# %%
code_dir = os.path.join(home_dir, 'pycrop-yield-prediction')
os.chdir(code_dir)
# !pwd
# !ls
# Out:
# /content/gdrive/My Drive/AYield/China/pycrop-yield-prediction
# cyp  data  diagrams  environment.yml  LICENSE  README.md  run.py

# %%
# fn
# !earthengine authenticate
# !earthengine task cancel all
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=1q6m6zGKK_gUbJ5zXqGxO48r83fLKTW5W-WRfFSYVZY&tc=CpZU3CPOhOhDeURCeseSkd5gNpK6V68HxY8VC8xcpGo&cc=gazOJcyyLUV0t25GHE_nhpr3hGTfXX8yBHXV3zXp9Js
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AdQt8qhZLFRnF0v_fCPjQrB4zybi3mW349rdxZflR1GevmUu5ZLRfabU0oo
#
# Successfully saved authorization token.

# %%
files = glob(os.path.join(code_dir, 'data', 'crop_yield-data_image', '*.tif'))
for ifile in tqdm(files):
  os.remove(ifile)

files = glob(os.path.join(code_dir, 'data', 'crop_yield-data_mask', '*.tif'))
for ifile in tqdm(files):
  os.remove(ifile)

files = glob(os.path.join(code_dir, 'data', 'crop_yield-data_temperature', '*.tif'))
for ifile in tqdm(files):
  os.remove(ifile)
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 334.40it/s]
# 100%|██████████| 29/29 [00:00<00:00, 221.44it/s]
# 100%|██████████| 32/32 [00:00<00:00, 306.45it/s]

# %%
# fin
# !pwd
# !python run.py process
# !python run.py export
# Out:
# /content/gdrive/My Drive/AYield/China/pycrop-yield-prediction
# MODISExporter TASK :
# {
#     "YIELD_DATA_PATH": "data/china_yield/wheat_2002-2018.csv",
#     "MASK_PATH": "data/crop_yield-data_mask",
#     "TEMPERATURE_PATH": "data/crop_yield-data_temperature",
#     "IMAGE_PATH": "data/crop_yield-data_image",
#     "CLEANED_DATA_PATH": "data/img_output",
#     "COUNTY_DATA_PATH": "data/county_data.csv",
#     "MODELS_PATH": "data/models",
#     "RANGE_DOWNLOAD": [
#         "2017-01-01",
#         "2018-12-31"
#     ],
#     "NUM_PROC_YEARS": 2
# }
# The Earth Engine package initialized successfully!
# 476it [00:03, 150.49it/s]
# Feature collection done
# Exporting to crop_yield-data_image/1_0 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_0', 'creation_timestamp_ms': 1661029030469, 'update_timestamp_ms': 1661029030469, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'DM7LPXTWQZDN5GXAC65UIZUT', 'name': 'projects/earthengine-legacy/operations/DM7LPXTWQZDN5GXAC65UIZUT'}
# Exporting to crop_yield-data_image/1_1 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_1', 'creation_timestamp_ms': 1661029042282, 'update_timestamp_ms': 1661029042282, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'UIEXWKP4DMZCUQ5AJUKQOALL', 'name': 'projects/earthengine-legacy/operations/UIEXWKP4DMZCUQ5AJUKQOALL'}
# Exporting to crop_yield-data_image/1_2 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_2', 'creation_timestamp_ms': 1661029055574, 'update_timestamp_ms': 1661029055574, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'YQV34NNWKI3B7RHGKVXUJ273', 'name': 'projects/earthengine-legacy/operations/YQV34NNWKI3B7RHGKVXUJ273'}
# Exporting to crop_yield-data_image/1_3 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_3', 'creation_timestamp_ms': 1661029068642, 'update_timestamp_ms': 1661029068642, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'NVEIRSEYTBE2YQP2IEO7JUML', 'name': 'projects/earthengine-legacy/operations/NVEIRSEYTBE2YQP2IEO7JUML'}
# Exporting to crop_yield-data_image/1_4 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_4', 'creation_timestamp_ms': 1661029081353, 'update_timestamp_ms': 1661029081353, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'MZ72ACP2AVMDGL4F255MKFNR', 'name': 'projects/earthengine-legacy/operations/MZ72ACP2AVMDGL4F255MKFNR'}
# Exporting to crop_yield-data_image/1_5 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_5', 'creation_timestamp_ms': 1661029092396, 'update_timestamp_ms': 1661029092396, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'YI3UGCHYTX3RHCMXD6HEWVPT', 'name': 'projects/earthengine-legacy/operations/YI3UGCHYTX3RHCMXD6HEWVPT'}
# Exporting to crop_yield-data_image/1_6 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_6', 'creation_timestamp_ms': 1661029105822, 'update_timestamp_ms': 1661029105822, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'UJVNKFLQPKABX2EAXMYTF6MN', 'name': 'projects/earthengine-legacy/operations/UJVNKFLQPKABX2EAXMYTF6MN'}
# Exporting to crop_yield-data_image/1_7 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_7', 'creation_timestamp_ms': 1661029118011, 'update_timestamp_ms': 1661029118011, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'SNZLOCI3MRTB3XARY7AS22HW', 'name': 'projects/earthengine-legacy/operations/SNZLOCI3MRTB3XARY7AS22HW'}
# Exporting to crop_yield-data_image/1_8 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_8', 'creation_timestamp_ms': 1661029129573, 'update_timestamp_ms': 1661029129573, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '55V6MRUXN3QQ777XISDIWJ4E', 'name': 'projects/earthengine-legacy/operations/55V6MRUXN3QQ777XISDIWJ4E'}
# Exporting to crop_yield-data_image/1_9 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_9', 'creation_timestamp_ms': 1661029141147, 'update_timestamp_ms': 1661029141147, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'WYZX5XMS2GQN4YGWSIUDZ7KR', 'name': 'projects/earthengine-legacy/operations/WYZX5XMS2GQN4YGWSIUDZ7KR'}
# Exporting to crop_yield-data_image/1_10 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_10', 'creation_timestamp_ms': 1661029154712, 'update_timestamp_ms': 1661029154712, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '5EJ5L7UJBZ5CW27ROSMPC4QT', 'name': 'projects/earthengine-legacy/operations/5EJ5L7UJBZ5CW27ROSMPC4QT'}
# Exporting to crop_yield-data_image/1_11 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_11', 'creation_timestamp_ms': 1661029168211, 'update_timestamp_ms': 1661029168211, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'KNTTC3WHV56DL3QWOOJSC3J7', 'name': 'projects/earthengine-legacy/operations/KNTTC3WHV56DL3QWOOJSC3J7'}
# Exporting to crop_yield-data_image/1_12 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_12', 'creation_timestamp_ms': 1661029181139, 'update_timestamp_ms': 1661029181139, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'VIEICY5FPRZ4MKLYO64ODOVP', 'name': 'projects/earthengine-legacy/operations/VIEICY5FPRZ4MKLYO64ODOVP'}
# Exporting to crop_yield-data_image/1_13 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_13', 'creation_timestamp_ms': 1661029196169, 'update_timestamp_ms': 1661029196169, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'LL4BJWLFAYZOH7SSZWOBANZC', 'name': 'projects/earthengine-legacy/operations/LL4BJWLFAYZOH7SSZWOBANZC'}
# Exporting to crop_yield-data_image/1_14 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_14', 'creation_timestamp_ms': 1661029209448, 'update_timestamp_ms': 1661029209448, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'NG2E5AXIP6SBO4QGBB6HCTPB', 'name': 'projects/earthengine-legacy/operations/NG2E5AXIP6SBO4QGBB6HCTPB'}
# Exporting to crop_yield-data_image/1_15 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_15', 'creation_timestamp_ms': 1661029222690, 'update_timestamp_ms': 1661029222690, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'LTDO3JILVZFPTSZFQDVA22QG', 'name': 'projects/earthengine-legacy/operations/LTDO3JILVZFPTSZFQDVA22QG'}
# Exporting to crop_yield-data_image/1_16 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_16', 'creation_timestamp_ms': 1661029234398, 'update_timestamp_ms': 1661029234398, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'D2P7QBH54LUX5UFKDDFXUFGX', 'name': 'projects/earthengine-legacy/operations/D2P7QBH54LUX5UFKDDFXUFGX'}
# Exporting to crop_yield-data_image/1_17 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_17', 'creation_timestamp_ms': 1661029246691, 'update_timestamp_ms': 1661029246691, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'DHJYZWRKHPOAIE5GHVK47JYC', 'name': 'projects/earthengine-legacy/operations/DHJYZWRKHPOAIE5GHVK47JYC'}
# Exporting to crop_yield-data_image/1_19 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_19', 'creation_timestamp_ms': 1661029258335, 'update_timestamp_ms': 1661029258335, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'VYDUC2QCTQCVSCYIYLTG7NZV', 'name': 'projects/earthengine-legacy/operations/VYDUC2QCTQCVSCYIYLTG7NZV'}
# Exporting to crop_yield-data_image/1_20 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_20', 'creation_timestamp_ms': 1661029271760, 'update_timestamp_ms': 1661029271760, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'WCAYWQ3FOMRL6AA6YYCZ7ZX7', 'name': 'projects/earthengine-legacy/operations/WCAYWQ3FOMRL6AA6YYCZ7ZX7'}
# Exporting to crop_yield-data_image/1_21 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_21', 'creation_timestamp_ms': 1661029284835, 'update_timestamp_ms': 1661029284835, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'TGEVXK2VX7QS45AUTZEM4XCE', 'name': 'projects/earthengine-legacy/operations/TGEVXK2VX7QS45AUTZEM4XCE'}
# Exporting to crop_yield-data_image/1_22 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_22', 'creation_timestamp_ms': 1661029297983, 'update_timestamp_ms': 1661029297983, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'TVVVEU4TZOOUCTT34AE6F4CD', 'name': 'projects/earthengine-legacy/operations/TVVVEU4TZOOUCTT34AE6F4CD'}
# Exporting to crop_yield-data_image/1_23 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_23', 'creation_timestamp_ms': 1661029312166, 'update_timestamp_ms': 1661029312166, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'KGAFT2T7QL44CEOZNU3XAI2H', 'name': 'projects/earthengine-legacy/operations/KGAFT2T7QL44CEOZNU3XAI2H'}
# Exporting to crop_yield-data_image/1_24 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_24', 'creation_timestamp_ms': 1661029325576, 'update_timestamp_ms': 1661029325576, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'VDCKE7XJJZQUFVAEURKQLKHN', 'name': 'projects/earthengine-legacy/operations/VDCKE7XJJZQUFVAEURKQLKHN'}
# Exporting to crop_yield-data_image/1_25 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_25', 'creation_timestamp_ms': 1661029337975, 'update_timestamp_ms': 1661029337975, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'ONHDN2XWWNX7LHRMHAX3YDS6', 'name': 'projects/earthengine-legacy/operations/ONHDN2XWWNX7LHRMHAX3YDS6'}
# Exporting to crop_yield-data_image/1_26 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_26', 'creation_timestamp_ms': 1661029351983, 'update_timestamp_ms': 1661029351983, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'NVTLH2626H6SPLM35R74L374', 'name': 'projects/earthengine-legacy/operations/NVTLH2626H6SPLM35R74L374'}
# Exporting to crop_yield-data_image/1_27 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_27', 'creation_timestamp_ms': 1661029363803, 'update_timestamp_ms': 1661029363803, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'OQVYMNCN4OXL3HIFGAOE45YJ', 'name': 'projects/earthengine-legacy/operations/OQVYMNCN4OXL3HIFGAOE45YJ'}
# Exporting to crop_yield-data_image/1_29 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_29', 'creation_timestamp_ms': 1661029375451, 'update_timestamp_ms': 1661029375451, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '6FSVPC5MCFMI4YMNSAE6BF6N', 'name': 'projects/earthengine-legacy/operations/6FSVPC5MCFMI4YMNSAE6BF6N'}
# Exporting to crop_yield-data_image/1_30 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_30', 'creation_timestamp_ms': 1661029388980, 'update_timestamp_ms': 1661029388980, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'PLRGRNPTVEUP4S4N4BNZGB5T', 'name': 'projects/earthengine-legacy/operations/PLRGRNPTVEUP4S4N4BNZGB5T'}
# Finished Exporting 29 files!
# Exporting to crop_yield-data_mask/1_0 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_0', 'creation_timestamp_ms': 1661029403104, 'update_timestamp_ms': 1661029403104, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '56EM5KTSKWFW3KMEC2H7UFNS', 'name': 'projects/earthengine-legacy/operations/56EM5KTSKWFW3KMEC2H7UFNS'}
# Exporting to crop_yield-data_mask/1_1 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_1', 'creation_timestamp_ms': 1661029415278, 'update_timestamp_ms': 1661029415278, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'TNHIPQUUDJ26MY7LEPDF5AKC', 'name': 'projects/earthengine-legacy/operations/TNHIPQUUDJ26MY7LEPDF5AKC'}
# Exporting to crop_yield-data_mask/1_2 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_2', 'creation_timestamp_ms': 1661029426791, 'update_timestamp_ms': 1661029426791, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'NOIZ63UT4TBZ3WK4OKNZ62IO', 'name': 'projects/earthengine-legacy/operations/NOIZ63UT4TBZ3WK4OKNZ62IO'}
# Exporting to crop_yield-data_mask/1_3 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_3', 'creation_timestamp_ms': 1661029439572, 'update_timestamp_ms': 1661029439572, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '2MUN7GHABHHF6CEQCCHLSW6J', 'name': 'projects/earthengine-legacy/operations/2MUN7GHABHHF6CEQCCHLSW6J'}
# Exporting to crop_yield-data_mask/1_4 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_4', 'creation_timestamp_ms': 1661029451101, 'update_timestamp_ms': 1661029451101, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'S6SQLYOVNSBMSNLEHOF6DJ7P', 'name': 'projects/earthengine-legacy/operations/S6SQLYOVNSBMSNLEHOF6DJ7P'}
# Exporting to crop_yield-data_mask/1_5 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_5', 'creation_timestamp_ms': 1661029464225, 'update_timestamp_ms': 1661029464225, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '3GC77WS2L6K5OYDPFIJBLKK3', 'name': 'projects/earthengine-legacy/operations/3GC77WS2L6K5OYDPFIJBLKK3'}
# Exporting to crop_yield-data_mask/1_6 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_6', 'creation_timestamp_ms': 1661029477512, 'update_timestamp_ms': 1661029477512, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'CPO2GOMVYTPNLG2475N7BQDC', 'name': 'projects/earthengine-legacy/operations/CPO2GOMVYTPNLG2475N7BQDC'}
# Exporting to crop_yield-data_mask/1_7 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_7', 'creation_timestamp_ms': 1661029491222, 'update_timestamp_ms': 1661029491222, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'NIMIRFZBRBBFUFIJS5Z2DEKH', 'name': 'projects/earthengine-legacy/operations/NIMIRFZBRBBFUFIJS5Z2DEKH'}
# Exporting to crop_yield-data_mask/1_8 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_8', 'creation_timestamp_ms': 1661029503046, 'update_timestamp_ms': 1661029503046, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'WSQJYYM7F2FVM6T7XNXF4VSP', 'name': 'projects/earthengine-legacy/operations/WSQJYYM7F2FVM6T7XNXF4VSP'}
# Exporting to crop_yield-data_mask/1_9 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_9', 'creation_timestamp_ms': 1661029515990, 'update_timestamp_ms': 1661029515990, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'DRC57ROYKXWHGEC6AGI2JNMP', 'name': 'projects/earthengine-legacy/operations/DRC57ROYKXWHGEC6AGI2JNMP'}
# Exporting to crop_yield-data_mask/1_10 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_10', 'creation_timestamp_ms': 1661029528026, 'update_timestamp_ms': 1661029528026, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'FIIA23GMAKGJ3KYVUKRLMWKA', 'name': 'projects/earthengine-legacy/operations/FIIA23GMAKGJ3KYVUKRLMWKA'}
# Exporting to crop_yield-data_mask/1_11 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_11', 'creation_timestamp_ms': 1661029545148, 'update_timestamp_ms': 1661029545148, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '3Z7MAHUS7B6D7L5GLA6U2VP3', 'name': 'projects/earthengine-legacy/operations/3Z7MAHUS7B6D7L5GLA6U2VP3'}
# Exporting to crop_yield-data_mask/1_12 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_12', 'creation_timestamp_ms': 1661029559612, 'update_timestamp_ms': 1661029559612, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'KNLQVZZKKB7F4POQYAY54INS', 'name': 'projects/earthengine-legacy/operations/KNLQVZZKKB7F4POQYAY54INS'}
# Exporting to crop_yield-data_mask/1_13 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_13', 'creation_timestamp_ms': 1661029571302, 'update_timestamp_ms': 1661029571302, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'Y7KG7MQ5HTWIMU2HFGKW7QYZ', 'name': 'projects/earthengine-legacy/operations/Y7KG7MQ5HTWIMU2HFGKW7QYZ'}
# Exporting to crop_yield-data_mask/1_14 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_14', 'creation_timestamp_ms': 1661029583151, 'update_timestamp_ms': 1661029583151, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'SZBDJ4PMRSRRQPC55U5YTI7W', 'name': 'projects/earthengine-legacy/operations/SZBDJ4PMRSRRQPC55U5YTI7W'}
# Exporting to crop_yield-data_mask/1_15 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_15', 'creation_timestamp_ms': 1661029597065, 'update_timestamp_ms': 1661029597065, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'YAWYB3HIUC5ILDTZTEGT25SD', 'name': 'projects/earthengine-legacy/operations/YAWYB3HIUC5ILDTZTEGT25SD'}
# Exporting to crop_yield-data_mask/1_16 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_16', 'creation_timestamp_ms': 1661029611474, 'update_timestamp_ms': 1661029611474, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'ZCGEGINWDXZV7HUBZJIATIAY', 'name': 'projects/earthengine-legacy/operations/ZCGEGINWDXZV7HUBZJIATIAY'}
# Exporting to crop_yield-data_mask/1_17 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_17', 'creation_timestamp_ms': 1661029626910, 'update_timestamp_ms': 1661029626910, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '7KZKEU6J5LSW3EJSIDZIL2ID', 'name': 'projects/earthengine-legacy/operations/7KZKEU6J5LSW3EJSIDZIL2ID'}
# Exporting to crop_yield-data_mask/1_19 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_19', 'creation_timestamp_ms': 1661029637742, 'update_timestamp_ms': 1661029637742, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '7MYZ4PTO3LYO3BVN3ZOE2LMW', 'name': 'projects/earthengine-legacy/operations/7MYZ4PTO3LYO3BVN3ZOE2LMW'}
# Exporting to crop_yield-data_mask/1_20 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_20', 'creation_timestamp_ms': 1661029651007, 'update_timestamp_ms': 1661029651007, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'V5S5BZYX2A4K2JOJOJZDSK75', 'name': 'projects/earthengine-legacy/operations/V5S5BZYX2A4K2JOJOJZDSK75'}
# Exporting to crop_yield-data_mask/1_21 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_21', 'creation_timestamp_ms': 1661029662378, 'update_timestamp_ms': 1661029662378, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'DLRJIJJMIA5RRRIRYJ3XUNDO', 'name': 'projects/earthengine-legacy/operations/DLRJIJJMIA5RRRIRYJ3XUNDO'}
# Exporting to crop_yield-data_mask/1_22 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_22', 'creation_timestamp_ms': 1661029675331, 'update_timestamp_ms': 1661029675331, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '4ESMCV2HJRLNM6G6KHDOXOTA', 'name': 'projects/earthengine-legacy/operations/4ESMCV2HJRLNM6G6KHDOXOTA'}
# Exporting to crop_yield-data_mask/1_23 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_23', 'creation_timestamp_ms': 1661029688306, 'update_timestamp_ms': 1661029688306, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'PR7XFJNVOOLCO2OBLDEFGB7C', 'name': 'projects/earthengine-legacy/operations/PR7XFJNVOOLCO2OBLDEFGB7C'}
# Exporting to crop_yield-data_mask/1_24 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_24', 'creation_timestamp_ms': 1661029700905, 'update_timestamp_ms': 1661029700905, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'T55PP7TYWKBEFDWRV7R4EAUT', 'name': 'projects/earthengine-legacy/operations/T55PP7TYWKBEFDWRV7R4EAUT'}
# Exporting to crop_yield-data_mask/1_25 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_25', 'creation_timestamp_ms': 1661029714303, 'update_timestamp_ms': 1661029714303, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'TAMDN7IOCOQUXN5W5DDMMQAN', 'name': 'projects/earthengine-legacy/operations/TAMDN7IOCOQUXN5W5DDMMQAN'}
# Exporting to crop_yield-data_mask/1_26 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_26', 'creation_timestamp_ms': 1661029727656, 'update_timestamp_ms': 1661029727656, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'W7LYYIPOEFIAOC5LGFBQJMUU', 'name': 'projects/earthengine-legacy/operations/W7LYYIPOEFIAOC5LGFBQJMUU'}
# Exporting to crop_yield-data_mask/1_27 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_27', 'creation_timestamp_ms': 1661029739122, 'update_timestamp_ms': 1661029739122, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'PFLJGIQXJSK5A5Z552UIMWHH', 'name': 'projects/earthengine-legacy/operations/PFLJGIQXJSK5A5Z552UIMWHH'}
# Exporting to crop_yield-data_mask/1_29 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_29', 'creation_timestamp_ms': 1661029753606, 'update_timestamp_ms': 1661029753606, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'PEVVKKT75TUVB2YUULCU65PT', 'name': 'projects/earthengine-legacy/operations/PEVVKKT75TUVB2YUULCU65PT'}
# Exporting to crop_yield-data_mask/1_30 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_30', 'creation_timestamp_ms': 1661029765109, 'update_timestamp_ms': 1661029765109, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'O4SI7ETLW4OHJC7YHY6W3TDL', 'name': 'projects/earthengine-legacy/operations/O4SI7ETLW4OHJC7YHY6W3TDL'}
# Finished Exporting 29 files!
# Exporting to crop_yield-data_temperature/1_0 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_0', 'creation_timestamp_ms': 1661029777066, 'update_timestamp_ms': 1661029777066, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'ELYIMGSXRGRQES2CCUE7XXYF', 'name': 'projects/earthengine-legacy/operations/ELYIMGSXRGRQES2CCUE7XXYF'}
# Exporting to crop_yield-data_temperature/1_1 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_1', 'creation_timestamp_ms': 1661029788720, 'update_timestamp_ms': 1661029788720, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'FIKOJLH72H626MUL75GP5QYH', 'name': 'projects/earthengine-legacy/operations/FIKOJLH72H626MUL75GP5QYH'}
# Exporting to crop_yield-data_temperature/1_2 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_2', 'creation_timestamp_ms': 1661029802207, 'update_timestamp_ms': 1661029802207, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'DPCYPN6EYQ2BMPEKI2MSG4UQ', 'name': 'projects/earthengine-legacy/operations/DPCYPN6EYQ2BMPEKI2MSG4UQ'}
# Exporting to crop_yield-data_temperature/1_3 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_3', 'creation_timestamp_ms': 1661029814047, 'update_timestamp_ms': 1661029814047, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'R5OZGA3YYDPYRZHA7TZ53ZBE', 'name': 'projects/earthengine-legacy/operations/R5OZGA3YYDPYRZHA7TZ53ZBE'}
# Exporting to crop_yield-data_temperature/1_4 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_4', 'creation_timestamp_ms': 1661029825133, 'update_timestamp_ms': 1661029825133, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'CNHDG7XOSB3UNSM33E5QJ7AR', 'name': 'projects/earthengine-legacy/operations/CNHDG7XOSB3UNSM33E5QJ7AR'}
# Exporting to crop_yield-data_temperature/1_5 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_5', 'creation_timestamp_ms': 1661029840701, 'update_timestamp_ms': 1661029840701, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'QXFGSNTADEZ5T2RWGIHWAAPE', 'name': 'projects/earthengine-legacy/operations/QXFGSNTADEZ5T2RWGIHWAAPE'}
# Exporting to crop_yield-data_temperature/1_6 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_6', 'creation_timestamp_ms': 1661029851978, 'update_timestamp_ms': 1661029851978, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'RYCKK4WXKBQXXW2NBXQPTCPG', 'name': 'projects/earthengine-legacy/operations/RYCKK4WXKBQXXW2NBXQPTCPG'}
# Exporting to crop_yield-data_temperature/1_7 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_7', 'creation_timestamp_ms': 1661029864514, 'update_timestamp_ms': 1661029864514, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'COXETUEZZDPINDTWAYD3SMF5', 'name': 'projects/earthengine-legacy/operations/COXETUEZZDPINDTWAYD3SMF5'}
# Exporting to crop_yield-data_temperature/1_8 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_8', 'creation_timestamp_ms': 1661029877265, 'update_timestamp_ms': 1661029877265, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '2N5QHOAMXNP7DIHRYSHUSOWJ', 'name': 'projects/earthengine-legacy/operations/2N5QHOAMXNP7DIHRYSHUSOWJ'}
# Exporting to crop_yield-data_temperature/1_9 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_9', 'creation_timestamp_ms': 1661029888686, 'update_timestamp_ms': 1661029888686, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'WBHNQZ2DMR73PXFLWXRGMPDF', 'name': 'projects/earthengine-legacy/operations/WBHNQZ2DMR73PXFLWXRGMPDF'}
# Exporting to crop_yield-data_temperature/1_10 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_10', 'creation_timestamp_ms': 1661029899829, 'update_timestamp_ms': 1661029899829, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'HPECIABWU2CCERLTQMOKM73F', 'name': 'projects/earthengine-legacy/operations/HPECIABWU2CCERLTQMOKM73F'}
# Exporting to crop_yield-data_temperature/1_11 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_11', 'creation_timestamp_ms': 1661029913171, 'update_timestamp_ms': 1661029913171, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'HYORBZMFHUQWJGUN3W64AGLG', 'name': 'projects/earthengine-legacy/operations/HYORBZMFHUQWJGUN3W64AGLG'}
# Exporting to crop_yield-data_temperature/1_12 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_12', 'creation_timestamp_ms': 1661029928189, 'update_timestamp_ms': 1661029928189, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '25Q3N2O54NYT3WPDOZKCCU4Y', 'name': 'projects/earthengine-legacy/operations/25Q3N2O54NYT3WPDOZKCCU4Y'}
# Exporting to crop_yield-data_temperature/1_13 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_13', 'creation_timestamp_ms': 1661029943068, 'update_timestamp_ms': 1661029943068, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'SJ5N56W5FJKHCTPRACHPUGGD', 'name': 'projects/earthengine-legacy/operations/SJ5N56W5FJKHCTPRACHPUGGD'}
# Exporting to crop_yield-data_temperature/1_14 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_14', 'creation_timestamp_ms': 1661029956394, 'update_timestamp_ms': 1661029956394, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '543IXOCVVRSJE5UE4DUM5MPW', 'name': 'projects/earthengine-legacy/operations/543IXOCVVRSJE5UE4DUM5MPW'}
# Exporting to crop_yield-data_temperature/1_15 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_15', 'creation_timestamp_ms': 1661029970039, 'update_timestamp_ms': 1661029970039, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'LLZHHIV5HHIW4EY6KNJFA4IB', 'name': 'projects/earthengine-legacy/operations/LLZHHIV5HHIW4EY6KNJFA4IB'}
# Exporting to crop_yield-data_temperature/1_16 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_16', 'creation_timestamp_ms': 1661029981507, 'update_timestamp_ms': 1661029981507, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'LKXEEPIJ7V22TOIIT25MGE5F', 'name': 'projects/earthengine-legacy/operations/LKXEEPIJ7V22TOIIT25MGE5F'}
# Exporting to crop_yield-data_temperature/1_17 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_17', 'creation_timestamp_ms': 1661029993759, 'update_timestamp_ms': 1661029993759, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '7OGRG57YOGYFB2EVQAU74GHE', 'name': 'projects/earthengine-legacy/operations/7OGRG57YOGYFB2EVQAU74GHE'}
# Exporting to crop_yield-data_temperature/1_19 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_19', 'creation_timestamp_ms': 1661030005247, 'update_timestamp_ms': 1661030005247, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'ERTO6SNTOP2ASTURTCRHF244', 'name': 'projects/earthengine-legacy/operations/ERTO6SNTOP2ASTURTCRHF244'}
# Exporting to crop_yield-data_temperature/1_20 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_20', 'creation_timestamp_ms': 1661030015734, 'update_timestamp_ms': 1661030015734, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'AXOSNGMKUIRAU6BW37UUNEIV', 'name': 'projects/earthengine-legacy/operations/AXOSNGMKUIRAU6BW37UUNEIV'}
# Exporting to crop_yield-data_temperature/1_21 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_21', 'creation_timestamp_ms': 1661030026967, 'update_timestamp_ms': 1661030026967, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'DASVESP2RIM5KUIEGEXLR753', 'name': 'projects/earthengine-legacy/operations/DASVESP2RIM5KUIEGEXLR753'}
# Exporting to crop_yield-data_temperature/1_22 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_22', 'creation_timestamp_ms': 1661030039186, 'update_timestamp_ms': 1661030039186, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'EY3UMPMKAX3AGVER6QRU5V72', 'name': 'projects/earthengine-legacy/operations/EY3UMPMKAX3AGVER6QRU5V72'}
# Exporting to crop_yield-data_temperature/1_23 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_23', 'creation_timestamp_ms': 1661030050183, 'update_timestamp_ms': 1661030050183, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'JYKRGPJEOHSWEAAESY7PEBPU', 'name': 'projects/earthengine-legacy/operations/JYKRGPJEOHSWEAAESY7PEBPU'}
# Exporting to crop_yield-data_temperature/1_24 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_24', 'creation_timestamp_ms': 1661030062319, 'update_timestamp_ms': 1661030062319, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '53AJMLWLDYIJEJASAXRK4BSK', 'name': 'projects/earthengine-legacy/operations/53AJMLWLDYIJEJASAXRK4BSK'}
# Exporting to crop_yield-data_temperature/1_25 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_25', 'creation_timestamp_ms': 1661030073969, 'update_timestamp_ms': 1661030073969, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'IBNTVJEF4L2EZC3W6PO6ZXR7', 'name': 'projects/earthengine-legacy/operations/IBNTVJEF4L2EZC3W6PO6ZXR7'}
# Exporting to crop_yield-data_temperature/1_26 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_26', 'creation_timestamp_ms': 1661030085849, 'update_timestamp_ms': 1661030085849, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '5KMYJBSYWADH4ALZLNIRUS2P', 'name': 'projects/earthengine-legacy/operations/5KMYJBSYWADH4ALZLNIRUS2P'}
# Exporting to crop_yield-data_temperature/1_27 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_27', 'creation_timestamp_ms': 1661030097544, 'update_timestamp_ms': 1661030097544, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '3ZZIQUTQIQJ7ZAJZQNDS54HD', 'name': 'projects/earthengine-legacy/operations/3ZZIQUTQIQJ7ZAJZQNDS54HD'}
# Exporting to crop_yield-data_temperature/1_29 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_29', 'creation_timestamp_ms': 1661030110306, 'update_timestamp_ms': 1661030110306, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'IVM6OUL3G7UYK5LSQLC653MM', 'name': 'projects/earthengine-legacy/operations/IVM6OUL3G7UYK5LSQLC653MM'}
# Exporting to crop_yield-data_temperature/1_30 with CRS=EPSG:4326
# Done: {'state': 'READY', 'description': '1_30', 'creation_timestamp_ms': 1661030121168, 'update_timestamp_ms': 1661030121168, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'PQWBZSHM72WDEHJWF4V7UREZ', 'name': 'projects/earthengine-legacy/operations/PQWBZSHM72WDEHJWF4V7UREZ'}
# Finished Exporting 29 files!
# Done exporting! Download the folders from your Google Drive

# %%
# !earthengine task list

fn
# !earthengine authenticate
# Out:
# PQWBZSHM72WDEHJWF4V7UREZ  Export.image  1_30  READY      ---
# IVM6OUL3G7UYK5LSQLC653MM  Export.image  1_29  READY      ---
# 3ZZIQUTQIQJ7ZAJZQNDS54HD  Export.image  1_27  READY      ---
# 5KMYJBSYWADH4ALZLNIRUS2P  Export.image  1_26  READY      ---
# IBNTVJEF4L2EZC3W6PO6ZXR7  Export.image  1_25  READY      ---
# 53AJMLWLDYIJEJASAXRK4BSK  Export.image  1_24  READY      ---
# JYKRGPJEOHSWEAAESY7PEBPU  Export.image  1_23  READY      ---
# EY3UMPMKAX3AGVER6QRU5V72  Export.image  1_22  READY      ---
# DASVESP2RIM5KUIEGEXLR753  Export.image  1_21  READY      ---
# AXOSNGMKUIRAU6BW37UUNEIV  Export.image  1_20  READY      ---
# ERTO6SNTOP2ASTURTCRHF244  Export.image  1_19  READY      ---
# 7OGRG57YOGYFB2EVQAU74GHE  Export.image  1_17  READY      ---
# LKXEEPIJ7V22TOIIT25MGE5F  Export.image  1_16  READY      ---
# LLZHHIV5HHIW4EY6KNJFA4IB  Export.image  1_15  READY      ---
# 543IXOCVVRSJE5UE4DUM5MPW  Export.image  1_14  READY      ---
# SJ5N56W5FJKHCTPRACHPUGGD  Export.image  1_13  READY      ---
# 25Q3N2O54NYT3WPDOZKCCU4Y  Export.image  1_12  READY      ---
# HYORBZMFHUQWJGUN3W64AGLG  Export.image  1_11  READY      ---
# HPECIABWU2CCERLTQMOKM73F  Export.image  1_10  READY      ---
# WBHNQZ2DMR73PXFLWXRGMPDF  Export.image  1_9   READY      ---
# 2N5QHOAMXNP7DIHRYSHUSOWJ  Export.image  1_8   READY      ---
# COXETUEZZDPINDTWAYD3SMF5  Export.image  1_7   READY      ---
# RYCKK4WXKBQXXW2NBXQPTCPG  Export.image  1_6   READY      ---
# QXFGSNTADEZ5T2RWGIHWAAPE  Export.image  1_5   READY      ---
# CNHDG7XOSB3UNSM33E5QJ7AR  Export.image  1_4   READY      ---
# R5OZGA3YYDPYRZHA7TZ53ZBE  Export.image  1_3   READY      ---
# DPCYPN6EYQ2BMPEKI2MSG4UQ  Export.image  1_2   READY      ---
# FIKOJLH72H626MUL75GP5QYH  Export.image  1_1   READY      ---
# ELYIMGSXRGRQES2CCUE7XXYF  Export.image  1_0   READY      ---
# O4SI7ETLW4OHJC7YHY6W3TDL  Export.image  1_30  READY      ---
# PEVVKKT75TUVB2YUULCU65PT  Export.image  1_29  READY      ---
# PFLJGIQXJSK5A5Z552UIMWHH  Export.image  1_27  READY      ---
# W7LYYIPOEFIAOC5LGFBQJMUU  Export.image  1_26  READY      ---
# TAMDN7IOCOQUXN5W5DDMMQAN  Export.image  1_25  READY      ---
# T55PP7TYWKBEFDWRV7R4EAUT  Export.image  1_24  READY      ---
# PR7XFJNVOOLCO2OBLDEFGB7C  Export.image  1_23  READY      ---
# 4ESMCV2HJRLNM6G6KHDOXOTA  Export.image  1_22  READY      ---
# DLRJIJJMIA5RRRIRYJ3XUNDO  Export.image  1_21  READY      ---
# V5S5BZYX2A4K2JOJOJZDSK75  Export.image  1_20  READY      ---
# 7MYZ4PTO3LYO3BVN3ZOE2LMW  Export.image  1_19  READY      ---
# 7KZKEU6J5LSW3EJSIDZIL2ID  Export.image  1_17  READY      ---
# ZCGEGINWDXZV7HUBZJIATIAY  Export.image  1_16  READY      ---
# YAWYB3HIUC5ILDTZTEGT25SD  Export.image  1_15  READY      ---
# SZBDJ4PMRSRRQPC55U5YTI7W  Export.image  1_14  READY      ---
# Y7KG7MQ5HTWIMU2HFGKW7QYZ  Export.image  1_13  READY      ---
# KNLQVZZKKB7F4POQYAY54INS  Export.image  1_12  READY      ---
# 3Z7MAHUS7B6D7L5GLA6U2VP3  Export.image  1_11  READY      ---
# FIIA23GMAKGJ3KYVUKRLMWKA  Export.image  1_10  READY      ---
# DRC57ROYKXWHGEC6AGI2JNMP  Export.image  1_9   READY      ---
# WSQJYYM7F2FVM6T7XNXF4VSP  Export.image  1_8   READY      ---
# NIMIRFZBRBBFUFIJS5Z2DEKH  Export.image  1_7   READY      ---
# CPO2GOMVYTPNLG2475N7BQDC  Export.image  1_6   READY      ---
# 3GC77WS2L6K5OYDPFIJBLKK3  Export.image  1_5   READY      ---
# S6SQLYOVNSBMSNLEHOF6DJ7P  Export.image  1_4   READY      ---
# 2MUN7GHABHHF6CEQCCHLSW6J  Export.image  1_3   READY      ---
# NOIZ63UT4TBZ3WK4OKNZ62IO  Export.image  1_2   READY      ---
# TNHIPQUUDJ26MY7LEPDF5AKC  Export.image  1_1   READY      ---
# 56EM5KTSKWFW3KMEC2H7UFNS  Export.image  1_0   RUNNING    ---
# PLRGRNPTVEUP4S4N4BNZGB5T  Export.image  1_30  RUNNING    ---
# 6FSVPC5MCFMI4YMNSAE6BF6N  Export.image  1_29  RUNNING    ---
# OQVYMNCN4OXL3HIFGAOE45YJ  Export.image  1_27  RUNNING    ---
# NVTLH2626H6SPLM35R74L374  Export.image  1_26  RUNNING    ---
# ONHDN2XWWNX7LHRMHAX3YDS6  Export.image  1_25  RUNNING    ---
# VDCKE7XJJZQUFVAEURKQLKHN  Export.image  1_24  RUNNING    ---
# KGAFT2T7QL44CEOZNU3XAI2H  Export.image  1_23  RUNNING    ---
# TVVVEU4TZOOUCTT34AE6F4CD  Export.image  1_22  RUNNING    ---
# TGEVXK2VX7QS45AUTZEM4XCE  Export.image  1_21  COMPLETED  ---
# WCAYWQ3FOMRL6AA6YYCZ7ZX7  Export.image  1_20  COMPLETED  ---
# VYDUC2QCTQCVSCYIYLTG7NZV  Export.image  1_19  RUNNING    ---
# DHJYZWRKHPOAIE5GHVK47JYC  Export.image  1_17  COMPLETED  ---
# D2P7QBH54LUX5UFKDDFXUFGX  Export.image  1_16  COMPLETED  ---
# LTDO3JILVZFPTSZFQDVA22QG  Export.image  1_15  COMPLETED  ---
# NG2E5AXIP6SBO4QGBB6HCTPB  Export.image  1_14  RUNNING    ---
# LL4BJWLFAYZOH7SSZWOBANZC  Export.image  1_13  COMPLETED  ---
# VIEICY5FPRZ4MKLYO64ODOVP  Export.image  1_12  COMPLETED  ---
# KNTTC3WHV56DL3QWOOJSC3J7  Export.image  1_11  COMPLETED  ---
# 5EJ5L7UJBZ5CW27ROSMPC4QT  Export.image  1_10  COMPLETED  ---
# WYZX5XMS2GQN4YGWSIUDZ7KR  Export.image  1_9   COMPLETED  ---
# 55V6MRUXN3QQ777XISDIWJ4E  Export.image  1_8   COMPLETED  ---
# SNZLOCI3MRTB3XARY7AS22HW  Export.image  1_7   COMPLETED  ---
# UJVNKFLQPKABX2EAXMYTF6MN  Export.image  1_6   COMPLETED  ---
# YI3UGCHYTX3RHCMXD6HEWVPT  Export.image  1_5   COMPLETED  ---
# MZ72ACP2AVMDGL4F255MKFNR  Export.image  1_4   COMPLETED  ---
# NVEIRSEYTBE2YQP2IEO7JUML  Export.image  1_3   COMPLETED  ---
# YQV34NNWKI3B7RHGKVXUJ273  Export.image  1_2   COMPLETED  ---
# UIEXWKP4DMZCUQ5AJUKQOALL  Export.image  1_1   COMPLETED  ---
# DM7LPXTWQZDN5GXAC65UIZUT  Export.image  1_0   COMPLETED  ---
# PUNKRMWX2SJRV5ISTFQYHNY4  Export.image  1_30  COMPLETED  ---
# RQ6QFVD4G6JXTDD7A7WSI4F3  Export.image  1_29  COMPLETED  ---
# DSXLEO6XBKVDGMRD5BPWGCYO  Export.image  1_27  COMPLETED  ---
# 56K3PYF3CXC4F6EHMIBOWTNO  Export.image  1_26  COMPLETED  ---
# NBTCI5C7F7S6VILHDKZZHP55  Export.image  1_25  COMPLETED  ---
# M2G7SEVS5KBR34YFECF3WHFW  Export.image  1_24  COMPLETED  ---
# FL2KOIRSX7ACEE3WJQATJXNF  Export.image  1_23  COMPLETED  ---
# 7OWRGYFQGULEOKDPH2WNKYLH  Export.image  1_22  COMPLETED  ---
# Z3EFMM2JL56WSNDEJLYNPMEE  Export.image  1_21  COMPLETED  ---
# NPSUQYO4OOJJKGAD6MYK3IRU  Export.image  1_20  COMPLETED  ---
# BCRNA2RWZ5POA6S7ZC6MLTD7  Export.image  1_19  COMPLETED  ---
# RHPZKZ6MUSERLHJJU5VMUXR6  Export.image  1_17  COMPLETED  ---
# RLWM527F7QA5BQE4IUH7DGM3  Export.image  1_16  COMPLETED  ---
# XQKSF23N6UMBVFR5QK5LOTGM  Export.image  1_15  COMPLETED  ---
# NYLR6UF2OLLPF2LFT3JT3IZP  Export.image  1_14  COMPLETED  ---
# PI2VKRACPFXAA5N77RY6BAYM  Export.image  1_13  COMPLETED  ---
# 3KHTB335FOFNIYTIDVNQNTUV  Export.image  1_12  COMPLETED  ---
# NBFJU3POSBJFJF5ESWD5QIJB  Export.image  1_11  COMPLETED  ---
# FYP34BSYWPFIGRKTRUJJPXGC  Export.image  1_10  COMPLETED  ---
# 5EOR7ORYAQT5MEMWS2D5HLH7  Export.image  1_9   COMPLETED  ---
# ZVG4VIAP77UG3G7DWZGCUG7C  Export.image  1_8   COMPLETED  ---
# 6B5E6N2SVD5K4SPPJBGEQPKW  Export.image  1_7   COMPLETED  ---
# 4YMLVNRBZIBDPJFFTSYH5AU2  Export.image  1_6   COMPLETED  ---
# S6J4Z7H27KA5K7PAN32N2ZE5  Export.image  1_5   COMPLETED  ---
# FX5CMQLH6UT2UIOHTMMHEKL2  Export.image  1_4   COMPLETED  ---
# MFTQWJH55Y7JI4XN4HNHBMDC  Export.image  1_3   COMPLETED  ---
# 7EG6EPECKFJ3MCOMEB3UDP4C  Export.image  1_2   COMPLETED  ---
# AR6X7R2RG3CCNDVKWX3I4B5S  Export.image  1_1   COMPLETED  ---
# ASIMXYZVDKU7VMDFSEIRDDVR  Export.image  1_0   COMPLETED  ---
# X5BKD6CXX4PS4SSSSWD6Z5QV  Export.image  1_30  COMPLETED  ---
# ZDDWE4MBEUD3CTUGJBBTYRH2  Export.image  1_29  COMPLETED  ---
# NJQK5T7SBD5WJ7NHTN6KADXH  Export.image  1_27  COMPLETED  ---
# RMLRGBR5LPM5NVJJ5W2VERJJ  Export.image  1_26  COMPLETED  ---
# 3M3OB7PZ6PS4LWQJEYKA5L4Y  Export.image  1_25  COMPLETED  ---
# YF2MGITV4YKXKSY6ZB5O5BWL  Export.image  1_24  COMPLETED  ---
# 5UQFUJZ2T2XVVYUES2WQ3QZS  Export.image  1_23  COMPLETED  ---
# U7YZKKW2C4G4IJGVWCGRVAF2  Export.image  1_22  COMPLETED  ---
# FQ7JHLQE2VZOZ2NNZJQ65YGB  Export.image  1_21  COMPLETED  ---
# D5O3U7HTDIFRBHLK3MNOTPPB  Export.image  1_20  COMPLETED  ---
# 4ZNVAFAXVWROVYGKWWBV7KOR  Export.image  1_19  COMPLETED  ---
# PVNCDYQVVE5HZMQJDR3DCKFY  Export.image  1_17  COMPLETED  ---
# BWFHWHLHBVC76URKLDESCICD  Export.image  1_16  COMPLETED  ---
# M5PCSRCADEHLCRV47RHNETSL  Export.image  1_15  COMPLETED  ---
# KVYTTIY6GLYW2CHDRUR3BXJG  Export.image  1_14  COMPLETED  ---
# 3IYDKISM754GSUZTUWHP4FVQ  Export.image  1_13  COMPLETED  ---
# KRJEQIJ3JYNRMHBEZ2YJPIP6  Export.image  1_12  COMPLETED  ---
# Y4Y6LL3HODUDQTIDWAETNO2D  Export.image  1_11  COMPLETED  ---
# FS3RQ72PGXRFJ74OTSG7LZKI  Export.image  1_10  COMPLETED  ---
# LXITFW6QMQC5OJ62UWRMP7RM  Export.image  1_9   COMPLETED  ---
# 2I3YQ43ZZ2E6VFREZPZWK6LP  Export.image  1_8   COMPLETED  ---
# OJHALNSGU5MZSJLZU6FIKIKB  Export.image  1_7   COMPLETED  ---
# P2Z5GKXEFO5EKDNCODOFOFKH  Export.image  1_6   COMPLETED  ---
# KXUPRJIZTYYXJYNEF7F62ELW  Export.image  1_5   COMPLETED  ---
# JCBZVUCDZRHLN3RLHA7354OT  Export.image  1_4   COMPLETED  ---
# XFKDX4HXX2U6TJACRFZ75ZRU  Export.image  1_3   COMPLETED  ---
# ZAUN7YT5D43MVAIWKUXAAWDJ  Export.image  1_2   COMPLETED  ---
# UCGW54FMMXSLYWPE2QWOOK3P  Export.image  1_1   COMPLETED  ---
# JO52V3XS56JGW2POPCELI7OX  Export.image  1_0   COMPLETED  ---
# VECYAKNSWK77QIFQLNSULGPT  Export.image  1_30  COMPLETED  ---
# BEF4SD76VFJRKJFLCMBA6XTZ  Export.image  1_29  COMPLETED  ---
# OAFNH73VPJV5TK45FDEHGFIF  Export.image  1_27  COMPLETED  ---
# 5PQXRHXIYWA55JQOPMHLBVDX  Export.image  1_26  COMPLETED  ---
# EGP5ENSUW6MCJSKRSEEY2WRY  Export.image  1_25  COMPLETED  ---
# EUEWA6I25SZVWE73ZWLX4QM4  Export.image  1_24  COMPLETED  ---
# RSP4C6OG5WOE2TPDXF6TRWEG  Export.image  1_23  COMPLETED  ---
# KRRCIE7ND4HIWIE23LCASNZ7  Export.image  1_22  COMPLETED  ---
# SRC42DDFJHGRVYY3YUI4J4N5  Export.image  1_21  COMPLETED  ---
# EZXKF5CR2X2KNPXG5NYDNDUZ  Export.image  1_20  COMPLETED  ---
# 52FJVHSTSNOQFA3HNCA3CLV4  Export.image  1_19  COMPLETED  ---
# 2TM3EOYZO3VR6CVPBDRMLY6E  Export.image  1_17  COMPLETED  ---
# 6XKJGWHZHR6WCEROXYQ3IVWR  Export.image  1_16  COMPLETED  ---
# UJZ667YOCH2CEDZE6O2OLNZU  Export.image  1_15  COMPLETED  ---
# IGB3JNKSFKSQYQ6KEZUBXGNQ  Export.image  1_14  COMPLETED  ---
# XDCEUERYQLPGB5PX2CZ57S26  Export.image  1_13  COMPLETED  ---
# 73MATSTNMUG5ZOXABFYNRFL5  Export.image  1_12  COMPLETED  ---
# YC4KMJDHOEKDPBAWCIBE52NS  Export.image  1_11  COMPLETED  ---
# H5EMPUU7KZMISLTD6UGIMGW6  Export.image  1_10  COMPLETED  ---
# 75EZJ4WNNVJM3YNBXSTF2C6Z  Export.image  1_9   COMPLETED  ---
# 5ZLCKVEA7CTOGPNQPXAIS34X  Export.image  1_8   COMPLETED  ---
# LBIRPQVFFG5K4QHOLNLF6TXM  Export.image  1_7   COMPLETED  ---
# LCVCDQQCDT7HO72ONAG55GCM  Export.image  1_6   COMPLETED  ---
# ZYBRUVZEFI7NYRXGQKY2EVTG  Export.image  1_5   COMPLETED  ---
# OZO4PXSPC553VOZGL6MW67IC  Export.image  1_4   COMPLETED  ---
# MTEPUBWN7LIBRRMB46Q2S52Z  Export.image  1_3   COMPLETED  ---
# 7K5XERNCA7FOGGUYOC72L34C  Export.image  1_2   COMPLETED  ---
# ORJFZW6UIE65ZWQ3WZBIGNEI  Export.image  1_1   COMPLETED  ---
# D4TD6JAOLIZCSRQQSHM6TYOM  Export.image  1_0   COMPLETED  ---
# 3GA34TAHLHYJXJBAUIYH7NOJ  Export.image  1_30  COMPLETED  ---
# HPZKS4VEKOVDPCV6JLMMJNVP  Export.image  1_29  COMPLETED  ---
# 7ASEL3RTGZUHVZWZF2MMQYVM  Export.image  1_27  COMPLETED  ---
# B7UK4VEKM76JJORM4HTTL5AH  Export.image  1_26  COMPLETED  ---
# DJX3FRMCB4PRLD2FRVOJ3NLN  Export.image  1_25  COMPLETED  ---
# ZPLRPHARH3NBKQZVPWC64S23  Export.image  1_24  COMPLETED  ---
# K2FZ4Y22EPLLH523WWLMTNSS  Export.image  1_23  COMPLETED  ---
# 62NKTEVX3YUTS7FP3SBX7C7T  Export.image  1_22  COMPLETED  ---
# JSCD5NSYHEDVMHIA7LLY233N  Export.image  1_21  COMPLETED  ---
# 4QOZYWYSRSZ5B5YHMZYBRPNP  Export.image  1_20  COMPLETED  ---
# 4H74MDAFANKZ6JPYJNCZQT2B  Export.image  1_19  COMPLETED  ---
# IRX5X5LYNIUVLLSS752WQ63F  Export.image  1_17  COMPLETED  ---
# DVKL6DVXHRUIYAY47VQKGRLN  Export.image  1_16  COMPLETED  ---
# VDKBJEP2F4BSVTKDE6TPGSQS  Export.image  1_15  COMPLETED  ---
# MMQYI5IG3KG4G3CLZNYHWP6G  Export.image  1_14  COMPLETED  ---
# LJD7ABGXDQVUMIWLH6IQOUSJ  Export.image  1_13  COMPLETED  ---
# ZHQWOG5UNMSFFW3W24X3NFMP  Export.image  1_12  COMPLETED  ---
# VHB335UE2N76FZIPZWVW2KBQ  Export.image  1_11  COMPLETED  ---
# F4X2VKDHKCS4TVGN56WSL6OV  Export.image  1_10  COMPLETED  ---
# IT7P3SAH2SB5XWWDAYW4ZQOV  Export.image  1_9   COMPLETED  ---
# ESTAPDLGBNZOPCNRDPXM654E  Export.image  1_8   COMPLETED  ---
# N66T5HFL5PN7FTMVP57RTM2S  Export.image  1_7   COMPLETED  ---
# VTMEULY2OCBRG2FTQKVYQ742  Export.image  1_6   COMPLETED  ---
# 3OEO4IJK6XTYSAPU4VG37Q3H  Export.image  1_5   COMPLETED  ---
# JZXFDIQLPBQV5KAGGOSXNUHZ  Export.image  1_4   COMPLETED  ---
# EXDBBBQ4JLDQIGE3LMLOQ62C  Export.image  1_3   COMPLETED  ---
# RYOMONVD2E3KMELDY4UNVPTI  Export.image  1_2   COMPLETED  ---
# U6VO5SXFMCCAIOM3YXLYQKAH  Export.image  1_1   COMPLETED  ---
# LK4AFSZ6MJK6XJXC4FMTGZSS  Export.image  1_0   COMPLETED  ---
# 3C54DKQSJEOKBL6MAZ6WWVIA  Export.image  1_30  COMPLETED  ---
# NJXLFOHFX4V6SKOZYKLY4FRJ  Export.image  1_29  COMPLETED  ---
# PTRUAZHHGQUTCM753ACQTFM2  Export.image  1_27  COMPLETED  ---
# ZPHU6SMTME5GSFUKSNDDCY2B  Export.image  1_26  COMPLETED  ---
# ASBECBQRHAIMS3HJMPIN5V3W  Export.image  1_25  COMPLETED  ---
# 7HHH4Q76C256ZPXNFZWL3NDK  Export.image  1_24  COMPLETED  ---
# 2S6XORHCNIKGGNE4DN2G3PNN  Export.image  1_23  COMPLETED  ---
# G3QUTRQ2T7KZZQW2W7XO2NYF  Export.image  1_22  COMPLETED  ---
# 5CGV3222URUE2WASEY5PQ5CZ  Export.image  1_21  COMPLETED  ---
# UVNIYEU3ANLEHZPO2KMQZ2E6  Export.image  1_20  COMPLETED  ---
# KKOGEGKSTMMKO2Z3I3B7MYFC  Export.image  1_19  COMPLETED  ---
# EDWFPS35TNGZHWDH5KRGELMV  Export.image  1_17  COMPLETED  ---
# FCU46YHVUZCANP64GGYIGZEJ  Export.image  1_16  COMPLETED  ---
# BLOQ4R3LMKXQNPRVUAT6BZF3  Export.image  1_15  COMPLETED  ---
# TLB5JHV3YNPOSCAKFBO2267R  Export.image  1_14  COMPLETED  ---
# J2CSZKYOH3ODNK6VLW5NWBZW  Export.image  1_13  COMPLETED  ---
# FRKGI33RJJ2XGOOS44T5QA27  Export.image  1_12  COMPLETED  ---
# KN6TD3GCDSP2FIDSPUMN2TJ2  Export.image  1_11  COMPLETED  ---
# DHYIPS5N7WP6ODMRF5N3YZUY  Export.image  1_10  COMPLETED  ---
# 6VFT7E6AZPAZKVAXKC47LMO4  Export.image  1_9   COMPLETED  ---
# DSXFSFIXGRD5H4ZVECUQ4RKF  Export.image  1_8   COMPLETED  ---
# UXTBBIJBB2ZXX72Y3F52E7LQ  Export.image  1_7   COMPLETED  ---
# UBAT75NKSIO5CLKHUYIHAOGC  Export.image  1_6   COMPLETED  ---
# EIOJEXCND7AMPGUMOKXIQGS7  Export.image  1_5   COMPLETED  ---
# QYAHYNU6JRH2N5AVHFUPIBA5  Export.image  1_4   COMPLETED  ---
# V4XB2OOVZNOIOLGVGH7ERCZS  Export.image  1_3   COMPLETED  ---
# YEOPFZGTCWRG4LOQGK67IYCG  Export.image  1_2   COMPLETED  ---
# LZ4T32M3NXNEOCA345KP7RDI  Export.image  1_1   COMPLETED  ---
# 2LVPQ56UXCJG72YQUPEH3WO5  Export.image  1_0   COMPLETED  ---
# DUCT3Q4MK4FIFMEUUTPQ6VIN  Export.image  1_30  COMPLETED  ---
# 3SNLBH4OU6EY2DEIZWL2RTGP  Export.image  1_29  COMPLETED  ---
# NB7O3KPUTZOW2ZKTCTL6YIAC  Export.image  1_27  COMPLETED  ---
# 25NRPR2HSVGQI4RGRTEZXUP4  Export.image  1_26  COMPLETED  ---
# DVAK722JPJ342APZ7IMHGVD3  Export.image  1_25  COMPLETED  ---
# CI5QDPPILT3VWSHPOG2IA3TM  Export.image  1_24  COMPLETED  ---
# 6FJGLUIOJUBRCR4BAZ7FUOAT  Export.image  1_23  COMPLETED  ---
# GCIXW74JEEUWFYBLS66OA3G6  Export.image  1_22  COMPLETED  ---
# JAWNRLMEHJLULHTS2M7IISBH  Export.image  1_21  COMPLETED  ---
# PH7C4BACGJ3S46SHPL4MU6OR  Export.image  1_20  COMPLETED  ---
# GYLETN4Q3RUCYEFYB7MGWXRY  Export.image  1_19  COMPLETED  ---
# 53423UB36GLAWZGQT6S5DRJE  Export.image  1_17  COMPLETED  ---
# TDXLI5KYGMW6MLJGFF6YMSQ3  Export.image  1_16  COMPLETED  ---
# 4NLDOO26ZBHB4MW6LJOSNWJD  Export.image  1_15  COMPLETED  ---
# X2KHXB24FWIYK25G4NYW3UPN  Export.image  1_14  COMPLETED  ---
# ML7OEFDW5KTK3DI6LZLJKV7N  Export.image  1_13  COMPLETED  ---
# KGGZF3ROJ4LYTEHWD2V7C5TA  Export.image  1_12  COMPLETED  ---
# NXVHRV2US4HG6I4AKOR44FJW  Export.image  1_11  COMPLETED  ---
# KNZKYZWPTIUWMXBIEYZNFBPM  Export.image  1_10  COMPLETED  ---
# 4T3NJOURSOOOQDJRJORJGCNE  Export.image  1_9   COMPLETED  ---
# RETDRIL7IG7IW54ZQ4CKFUNA  Export.image  1_8   COMPLETED  ---
# DN6DR6VMW6Y5DQOJK4LV2RMX  Export.image  1_7   COMPLETED  ---
# LCH3N6FC7RYNWD5JMX4HAPMQ  Export.image  1_6   COMPLETED  ---
# CNANKZ3NTKLS4GYENEBNHUWT  Export.image  1_5   COMPLETED  ---
# F2HZXZVGPVRYYPKQKGHWIJEY  Export.image  1_4   COMPLETED  ---
# 4VWXZQP6TS5KKPSGQZENNFJR  Export.image  1_3   COMPLETED  ---
# IH52WZXJAFAGF3UP2BGBWK6S  Export.image  1_2   COMPLETED  ---
# 5REKB6VZJWPWD5IWHPECTDOS  Export.image  1_1   COMPLETED  ---
# J4EMBJMOUUAQWWJWR3IPM6J5  Export.image  1_0   COMPLETED  ---
# FJO4IVHO6KTY4ZCI2YXOGN47  Export.image  1_30  COMPLETED  ---
# 57EC4P4Q64COUAFLF5CTPDXV  Export.image  1_29  COMPLETED  ---
# RXV3OQEY4SCGUENODCJKF2TT  Export.image  1_27  COMPLETED  ---
# YIA623SDBKIZS3WNTR7ICAQT  Export.image  1_26  COMPLETED  ---
# 2QMNIOEYLDIKDI4DA5B4J3NC  Export.image  1_25  COMPLETED  ---
# CWUK3YEUG6H7KW6YABXFFW4F  Export.image  1_24  COMPLETED  ---
# 2CVY5VOM2CJI5ZJ4AKHE6IRI  Export.image  1_23  COMPLETED  ---
# KIRXU7UY6FMHDHVVONJEFGG5  Export.image  1_22  COMPLETED  ---
# WBZAWQUJ5JIVIFSGOCVJVVPZ  Export.image  1_21  COMPLETED  ---
# XYIEW4M3TCNXTMM4EOL3COIH  Export.image  1_20  COMPLETED  ---
# L25KQIZ5YSBR3PR4S56I3FQQ  Export.image  1_19  COMPLETED  ---
# ZWFDBJMYBKXTJHIMOY7ANGHT  Export.image  1_17  COMPLETED  ---
# SIXAJCXMAT3MQBYN7YFYDL7M  Export.image  1_16  COMPLETED  ---
# DHD3C6NJCDLG263YNXD43Z7D  Export.image  1_15  COMPLETED  ---
# CO7DWT7FGYRN2U6MPAWYVOWS  Export.image  1_14  COMPLETED  ---
# TLWIWKIF42NXRRDEQV2YA23G  Export.image  1_13  COMPLETED  ---
# TNLRJ3HTTCHUR6XRXFHHP3ZU  Export.image  1_12  COMPLETED  ---
# KEFKFDGPBKYAOMFEN7AITNHG  Export.image  1_11  COMPLETED  ---
# I4XBMC32KUCOGT7HH2LQEMIW  Export.image  1_10  COMPLETED  ---
# JNT2SJZDW4G6LLR3NQGE2UNE  Export.image  1_9   COMPLETED  ---
# D2NKDGGHUKJ33GCIWX3ZSLUI  Export.image  1_8   COMPLETED  ---
# X3XQITS2TDE7EGH35U4Q6B76  Export.image  1_7   COMPLETED  ---
# 6FOHYIKBLB4KRNNLZDOFB6KB  Export.image  1_6   COMPLETED  ---
# JI3B5BAUX52GCGHUESF6OTMH  Export.image  1_5   COMPLETED  ---
# KBVOS5I5BVQBIOXL3NE7744C  Export.image  1_4   COMPLETED  ---
# YOGAMU3OSHONAFBNKYFN6B55  Export.image  1_3   COMPLETED  ---
# UCAZOTV7HQJQIYZHE2XWLKMI  Export.image  1_2   COMPLETED  ---
# PYEREIX4BO3D2XG3XVZW3AGG  Export.image  1_1   COMPLETED  ---
# PL627WNBXFSRZKCUNIPTL66S  Export.image  1_0   COMPLETED  ---
# D2FUCUSLHSSCAI44WPHM6O3C  Export.image  1_30  COMPLETED  ---
# PVPG3A5XN4WAOPQE6MAGL5J3  Export.image  1_29  COMPLETED  ---
# MFIFCOVFPHJZDQEYVF4FW2BJ  Export.image  1_27  COMPLETED  ---
# YFH2KIFLLLZQBHBXCBQQ4NIQ  Export.image  1_26  COMPLETED  ---
# WV2DIHISG7UED334RZGIDYWR  Export.image  1_25  COMPLETED  ---
# S6XCECK4UIEAWACEN2HQECSF  Export.image  1_24  COMPLETED  ---
# VTWSQ5VSIGIGNUQCAQLDRTR4  Export.image  1_23  COMPLETED  ---
# DUQLGDP2RB2KYAPQS3Y2LA5X  Export.image  1_22  COMPLETED  ---
# DQ47ZP3ALPF7F5DQRYX2QCFN  Export.image  1_21  COMPLETED  ---
# MQHD5SZRORQVQAYSY72YOV75  Export.image  1_20  COMPLETED  ---
# ONZ3VY2O2Z7272F5SWMJW6E4  Export.image  1_19  COMPLETED  ---
# XIOP76YOTRDVMHWG6SKEWS24  Export.image  1_17  COMPLETED  ---
# HNAYBA5EIFJRIJV6WNUU5QUS  Export.image  1_16  COMPLETED  ---
# 77AFIFEIHGI4ROYF53RBVRFN  Export.image  1_15  COMPLETED  ---
# XBHDHQSNUOI624N4RXEL536B  Export.image  1_14  COMPLETED  ---
# YB2V3AVFEO2J3QEEGTF23CIP  Export.image  1_13  COMPLETED  ---
# FMT3HGR3J2O6SL76SAD2WIMP  Export.image  1_12  COMPLETED  ---
# 6P5I554GKS2ZMCT2BU2OR2B2  Export.image  1_11  COMPLETED  ---
# RSP3BVZWGBXZAHKKRC64VGJY  Export.image  1_10  COMPLETED  ---
# YHBE76OYIVEVC42EH3WGGTGU  Export.image  1_9   COMPLETED  ---
# ZDY3NDG5U6NPHXPNG4FNRNAG  Export.image  1_8   COMPLETED  ---
# E3NJI4OAYQEOMCW7TO6YWQGB  Export.image  1_7   COMPLETED  ---
# XTANBQYKIPXXHGLD4UTNKRJF  Export.image  1_6   COMPLETED  ---
# WM2SYXQEXH62FRHDCHMWKSWO  Export.image  1_5   COMPLETED  ---
# 6RR4Z3O3VKOIIO2IRV5OVYB7  Export.image  1_4   COMPLETED  ---
# WWNYKKXJUZYY5WXC7RCLFJJO  Export.image  1_3   COMPLETED  ---
# VUNXL34Y43AKXSPVKCO3UYJX  Export.image  1_2   COMPLETED  ---
# SALPYWZO7OHUUTAWQFMKISUQ  Export.image  1_1   COMPLETED  ---
# GJLAPHGSA2NW5T2JCKBNVBYI  Export.image  1_0   COMPLETED  ---
# BKELXNFS5W7SSUGCJFDKETXP  Export.image  1_30  COMPLETED  ---
# ELTILC2BMTZSN3WJTTTNFD4E  Export.image  1_29  COMPLETED  ---
# 2W45K4QWJHW4ON2YMWYHALDJ  Export.image  1_27  COMPLETED  ---
# ZY7R6JBVAGGUVCBIW6XPLID2  Export.image  1_26  COMPLETED  ---
# XWCXEBUKKYKSIQO5UUP33FGL  Export.image  1_25  COMPLETED  ---
# QQBCLICATXDGDBLRNH55F46R  Export.image  1_24  COMPLETED  ---
# HZOLQDXQP2FAP3PIA4BUQOWC  Export.image  1_23  COMPLETED  ---
# 3CTKCCPMIXQABTX4SOK4IABX  Export.image  1_22  COMPLETED  ---
# LUTL5H2CSNGCMPETYZX2KJSK  Export.image  1_21  COMPLETED  ---
# VEHRKP3UMJHUDEBNZWDLENIB  Export.image  1_20  COMPLETED  ---
# 2ZQICCR7YLHGMVSO4WCIIL3Y  Export.image  1_19  COMPLETED  ---
# BHWKNBI3FAXBW4UEGGL5QLBG  Export.image  1_17  COMPLETED  ---
# ID55GL2EY6QP245BKKQQ4EHF  Export.image  1_16  COMPLETED  ---
# 4YSNKDHNCWVTLW2GIJPYWYI7  Export.image  1_15  COMPLETED  ---
# VHYZY2IE4ZHZ2MW6FGJLNMRW  Export.image  1_14  COMPLETED  ---
# KRPONGKD35YZ6FKPZAQ4OASA  Export.image  1_13  COMPLETED  ---
# CH6U6LCTMYKFEFHAREZ2HSYJ  Export.image  1_12  COMPLETED  ---
# LL3BI3ELFIT6H2WCTJ2UY6D5  Export.image  1_11  COMPLETED  ---
# OHIX6RJOWPU4BZ27HKIRENUR  Export.image  1_10  COMPLETED  ---
# ICNLWV7T7AMHQSZZHL5CLTRL  Export.image  1_9   COMPLETED  ---
# G56X673BBGJX2G3FJYS5EWIV  Export.image  1_8   COMPLETED  ---
# D5CAMFPCZ37TUJ5ETGGPAFBJ  Export.image  1_7   COMPLETED  ---
# 2L7US5Q4XI7DP74ISOOHHOJW  Export.image  1_6   COMPLETED  ---
# AMJORLVG7VI2T3V3TG4WEN2E  Export.image  1_5   COMPLETED  ---
# M7CFVTR62H54X7ES3EOTFHJX  Export.image  1_4   COMPLETED  ---
# WZLLUQTZ2JBRMJHTSV4M3AZ7  Export.image  1_3   COMPLETED  ---
# UL27LN7Z5GFJF7BAWVILYMHB  Export.image  1_2   COMPLETED  ---
# TYYVUY6ANPESBHJM64E5EFJ7  Export.image  1_1   COMPLETED  ---
# 5VTNAJCLATIMPNULLG77C2T6  Export.image  1_0   COMPLETED  ---
# 3LTOHAT56AOETFS54TIPK5YN  Export.image  1_30  COMPLETED  ---
# QBEVZJD47XS2ZTPE4D4HW7LR  Export.image  1_29  COMPLETED  ---
# JGZBFMMZZZIGIUMLHCBKD2AC  Export.image  1_27  COMPLETED  ---
# 45PK6WXAA67BM5B2EYIOOLB5  Export.image  1_26  COMPLETED  ---
# SLCJAXDJDWKAWB2WUJO6Y3IO  Export.image  1_25  COMPLETED  ---
# FYUTJ5CMS6J4UP3H5YCR5RU6  Export.image  1_24  COMPLETED  ---
# ZHCM4VWHP6R3BGAJML2NPJYV  Export.image  1_23  COMPLETED  ---
# EGRCPY6OJ6JQ57DYGWVRG4QN  Export.image  1_22  COMPLETED  ---
# 7SF3X5QUEA67NUMPDPXKHJ6Z  Export.image  1_21  COMPLETED  ---
# YJ2XKBYQ7I3JDNPGLNHRP6E4  Export.image  1_20  COMPLETED  ---
# 7B6ZPMDBE75PSZVX6BBPSXUZ  Export.image  1_19  COMPLETED  ---
# BQQTN7K37YNSGOM37YIRP6JY  Export.image  1_17  COMPLETED  ---
# WZZPORDMQ6MVHEB4PZ5P6IR6  Export.image  1_16  COMPLETED  ---
# IXYKJWMJBYYBELF4Q272C74J  Export.image  1_15  COMPLETED  ---
# VIR5Q66IB2LGSSZQFSZWSKU4  Export.image  1_14  COMPLETED  ---
# VHJVQ3DHTLJFTTGMTL3MXXSD  Export.image  1_13  COMPLETED  ---
# NGNOB5DRBXP5E5Q2XY7ZWSWQ  Export.image  1_12  COMPLETED  ---
# KCRSXYCDFCT3ZYFELUFMUDXQ  Export.image  1_11  COMPLETED  ---
# 3XR4TCE7UZWHAVWVLPJUUH2H  Export.image  1_10  COMPLETED  ---
# EMWUUPUMNQCVG5GGLPSKUZUA  Export.image  1_9   COMPLETED  ---
# EH7MVYAMWG7MXSXSSBFLC7OC  Export.image  1_8   COMPLETED  ---
# L44ZUAHFHCCWPGJMVM2WNNUO  Export.image  1_7   COMPLETED  ---
# NOPCTUORFKS3PV5YON3NWIYI  Export.image  1_6   COMPLETED  ---
# W6TDIOZ7SNYRGIALWBQWVOU5  Export.image  1_5   COMPLETED  ---
# OM4ZK4RI24UXVGVLNK6E765O  Export.image  1_4   COMPLETED  ---
# SSR56FETBJNAR5PDG7UMBZO5  Export.image  1_3   COMPLETED  ---
# PX363DMRQDMEY5Q25LGT5A6E  Export.image  1_2   COMPLETED  ---
# 7ZN5N3FUFFCTF6O2WBDF4B6B  Export.image  1_1   COMPLETED  ---
# AZTA4Y3UWYDBIDAZGOLPH3RY  Export.image  1_0   COMPLETED  ---
# UAX7SRGXPELTAF5G6DLE2STZ  Export.image  1_30  COMPLETED  ---
# GIAS2L6IKZ7Z6PTHGAOSYT5E  Export.image  1_29  COMPLETED  ---
# 22RVYMSIIUZKL3YJX7CLH6FP  Export.image  1_27  COMPLETED  ---
# UHQSGCVW7ATFPNSSKBISYGDG  Export.image  1_26  COMPLETED  ---
# VRXHANVJUTDUQDEYW3MVXWPD  Export.image  1_25  COMPLETED  ---
# HJNXDA23FD5VJUPJQI3RNLGX  Export.image  1_24  COMPLETED  ---
# NIMZJTZOYKOAKBRWCKQB2EV6  Export.image  1_23  COMPLETED  ---
# 3SCIYIAURJ7NEG67QNAUFYTK  Export.image  1_22  COMPLETED  ---
# ET2GYGNVHTMFPKSMDGP3YRL4  Export.image  1_21  COMPLETED  ---
# LRN3S6DHJXZ4JZR4QDTSBBAF  Export.image  1_20  COMPLETED  ---
# XE4RE5WAEPDY6KN26TOYAZJB  Export.image  1_19  COMPLETED  ---
# N5Z7IGEDCU4Y3S3S4YCUW6NI  Export.image  1_17  COMPLETED  ---
# U2IOBRTIIJV5NVG42CD2BG5I  Export.image  1_16  COMPLETED  ---
# TQDDQ6ASFLI36PKSZYTHLDEM  Export.image  1_15  COMPLETED  ---
# MSXYZ3PEQVDWWZMT2QXL4G5R  Export.image  1_14  COMPLETED  ---
# DHSPALNJGVITV3ZCCNWKFU4Q  Export.image  1_13  COMPLETED  ---
# MR7BCGKNECOI4BVOXQMQC6R7  Export.image  1_12  COMPLETED  ---
# 6M6UE5GKZPWCUKDOYCVPUEZI  Export.image  1_11  COMPLETED  ---
# YTMPEBYZV5Q5Z32F3QWFIAPJ  Export.image  1_10  COMPLETED  ---
# RL65TLNOGVUOQBB3332WOZJO  Export.image  1_9   COMPLETED  ---
# OODRGDKZOMZQKEB66VAFRXEU  Export.image  1_8   COMPLETED  ---
# QNNYVKC3BLS3BGQ2JAY5ZOD2  Export.image  1_7   COMPLETED  ---
# 6NUZJAZDPO4VXA45RPXN6OCW  Export.image  1_6   COMPLETED  ---
# 4LPGSDFBYHPS4FZHMY5CXFEK  Export.image  1_5   COMPLETED  ---
# 7AM5KCDI5PAFYDF2EO4GGKKF  Export.image  1_4   COMPLETED  ---
# E47IHUWPPIFWP7EKCGMMD7UG  Export.image  1_3   COMPLETED  ---
# 4DSSBVJNYYEJSC5OGUYAQ5MB  Export.image  1_2   COMPLETED  ---
# ZZ33C7OFDPJSBWREAR7TWBWX  Export.image  1_1   COMPLETED  ---
# GPF75T3SRACX6EHQ7HDMNJMY  Export.image  1_0   COMPLETED  ---
# QEERK2YOXE6MMR5FYMODWUIW  Export.image  1_30  COMPLETED  ---
# YGDU3IZD6K7LZX4R56SJWD64  Export.image  1_29  COMPLETED  ---
# 5ARHURQSACBQON7T32JBREA3  Export.image  1_27  COMPLETED  ---
# NFD27PGMTZLTAGTXNVZ7TEOX  Export.image  1_26  COMPLETED  ---
# NPW6YC447APNAEJ6YCFEU3JB  Export.image  1_25  COMPLETED  ---
# OXN7RAIA26LU57LH644AISUG  Export.image  1_24  COMPLETED  ---
# WHQ2PD7TAYT2YIEKYVTMHENE  Export.image  1_23  COMPLETED  ---
# RSL756MZGQ5DKLC4N5A24GW6  Export.image  1_22  COMPLETED  ---
# 7SWTX2FIW4TZHSOKYVKQFLP7  Export.image  1_21  COMPLETED  ---
# LI3ABIU4JEPA23GA4G5HUYP2  Export.image  1_20  COMPLETED  ---
# ZLWEEAJ6HR5T5VF25R7S7ASC  Export.image  1_19  COMPLETED  ---
# TBVPCQ5IRK2Q2ACM7ULZTHSU  Export.image  1_17  COMPLETED  ---
# AGISMKBN3NFB4XOBM6QTMCFZ  Export.image  1_16  COMPLETED  ---
# NIQVZNWNZFNULS5OMLDYZII6  Export.image  1_15  COMPLETED  ---
# 44PPZP3NC2JYED3RCK453NFG  Export.image  1_14  COMPLETED  ---
# NPLKVGWPVCJIPNAMMPIN42OL  Export.image  1_13  COMPLETED  ---
# ND3AFOZXFXEDXOGM6M6UBKWM  Export.image  1_12  COMPLETED  ---
# J6TM2ZQDFSPX7F3ALCZE3UMW  Export.image  1_11  COMPLETED  ---
# MEO7MU5FFG7TLN3SBQQGKEYN  Export.image  1_10  COMPLETED  ---
# IWAPOZDYSPBKGYDND5YLAU22  Export.image  1_9   COMPLETED  ---
# MWVZEKZVD2OGHNWMRXBNREYH  Export.image  1_8   COMPLETED  ---
# JJTUQRUM23G6D4L3KUYU2FQ4  Export.image  1_7   COMPLETED  ---
# TKXXMJRHTNLKIDJCIHK6S2NY  Export.image  1_6   COMPLETED  ---
# CQDBXKRH375T26U27WD7RKYG  Export.image  1_5   COMPLETED  ---
# KJB2BWSL2BWSLNEHD7HGBANI  Export.image  1_4   COMPLETED  ---
# VAZND4WHAQYCXYMKKGWIXGMS  Export.image  1_3   COMPLETED  ---
# 2PO4O4S3W7WBKYH56EZCUAT3  Export.image  1_2   COMPLETED  ---
# ERREUA75GHUC5DE6HYLQPILA  Export.image  1_1   COMPLETED  ---
# RKAPUERCP4DG77LQTED3BWBP  Export.image  1_0   COMPLETED  ---
# OPMBCFHCI2VMVGZ5FETPWLPR  Export.image  1_30  COMPLETED  ---
# GA63XSITT3GFZTYH4DAJLRWF  Export.image  1_29  COMPLETED  ---
# KLXDXABC6T6TOW2SZD6F2ECF  Export.image  1_27  COMPLETED  ---
# 6U7RSY77NLNVYL7KLMPFOVYE  Export.image  1_26  COMPLETED  ---
# A7TLD5CO5BXSKT42DGGTECCD  Export.image  1_25  COMPLETED  ---
# 3SMXNRIBAMWE6HY4NPAWXEYS  Export.image  1_24  COMPLETED  ---
# G2ONK6DQHTKJTMV4ZSV6T46W  Export.image  1_23  COMPLETED  ---
# 2RMTKGJE5TKZOJFJNCQPUXR3  Export.image  1_22  COMPLETED  ---
# JOSR3PR7MOEJ3JYG4TY6RYUD  Export.image  1_21  COMPLETED  ---
# JKOGTYILGYT57RRBNLXEFP4P  Export.image  1_20  COMPLETED  ---
# 6CCMOQCHZOYMV4PE47OG7W55  Export.image  1_19  COMPLETED  ---
# IS4WFEPD3FGYZLI6NZTWZEJJ  Export.image  1_17  COMPLETED  ---
# I3FT7XOEWFYEETXO3ZYPEOHU  Export.image  1_16  COMPLETED  ---
# 5BLQVCMXUU4ROB5FCFS6GLGV  Export.image  1_15  COMPLETED  ---
# R62OL3H4E7APJH5NALW65JJ3  Export.image  1_14  COMPLETED  ---
# UXJCNU4YYAZ6YRPZHH4HKGLB  Export.image  1_13  COMPLETED  ---
# HFW3ORK4OIUPSIF7TILFL5P2  Export.image  1_12  COMPLETED  ---
# ZS7YQJYIFWFTVKOV4I76HXMW  Export.image  1_11  COMPLETED  ---
# MDN66AEHLRVOB5A2HOBULDFT  Export.image  1_10  COMPLETED  ---
# J4XMAS2W7ULSYVCT6OKJUDWL  Export.image  1_9   COMPLETED  ---
# E2FULNHDFQBKBPQWXYQ2KWX3  Export.image  1_8   COMPLETED  ---
# QCIFG4274J3KGD7DIWEY3LVJ  Export.image  1_7   COMPLETED  ---
# KOKZAFDQ5BUA2ZC2CPEESCCX  Export.image  1_6   COMPLETED  ---
# R5OZKFNVSR7WZG4L4NRLOHJ7  Export.image  1_5   COMPLETED  ---
# V3GYRHTNBAPXLM5T4GK4SQPC  Export.image  1_4   COMPLETED  ---
# KVQXRKAMUQHFJBUIAF35ZFQ5  Export.image  1_3   COMPLETED  ---
# EO7YA2L7EUSLHCUVIOBPF346  Export.image  1_2   COMPLETED  ---
# ODW65HP7HMHQFKUO6TGCHPIL  Export.image  1_1   COMPLETED  ---
# WOTEWPWFBCRB5TV3HDA6ASVF  Export.image  1_0   COMPLETED  ---
# GR3NQNXRH537MYYG76UCYZWD  Export.image  1_30  COMPLETED  ---
# B2U5CXZO2BZZRQ7PZCWCVOF4  Export.image  1_29  COMPLETED  ---
# PSQJZPVXSPWRS32OZMMIENHP  Export.image  1_27  COMPLETED  ---
# K2V774JQTTRLZOG74CWNQU3B  Export.image  1_26  COMPLETED  ---
# AZK4JHJZGWNHVTBUU64KIRH5  Export.image  1_25  COMPLETED  ---
# Q3KTO27RRNFBRBUBISNEELWF  Export.image  1_24  COMPLETED  ---
# PVEOLFCHERVLUDIMD2UE5VUC  Export.image  1_23  COMPLETED  ---
# 3NWW5OIXCFUW26IBK22GFAJ6  Export.image  1_22  COMPLETED  ---
# UBXPUKCWMKYN74LVFJTQ5EL2  Export.image  1_21  COMPLETED  ---
# UNNKISCSJN3ZUCKF72S5B7LY  Export.image  1_20  COMPLETED  ---
# ZN4KBFJP4NOAAOHLKZOCQQB3  Export.image  1_19  COMPLETED  ---
# A5A22X4IFU2CY5KIZRRWRCKF  Export.image  1_17  COMPLETED  ---
# UVFK6Q2WV7E6BJJSNAHDQDSB  Export.image  1_16  COMPLETED  ---
# ATPQJ523LMNTLXTBUA6EZVNR  Export.image  1_15  COMPLETED  ---
# DPA5Y5SEDJ43UCOYY7E6GS7H  Export.image  1_14  COMPLETED  ---
# EEIDQAAWIRS5TK6UMCW7Z3IE  Export.image  1_13  COMPLETED  ---
# DTRNAPJK7FAG66UMOHMBLQSH  Export.image  1_12  COMPLETED  ---
# MJQBU5WOFUUFDJIDMGNBVYZ2  Export.image  1_11  COMPLETED  ---
# GQCOLV7VLMRFMNUSQH2MCIUW  Export.image  1_10  COMPLETED  ---
# ORGVDSJVKB46DIIESZ64PX4V  Export.image  1_9   COMPLETED  ---
# QZB7ZOZCLEMINE2IMY3DFPEJ  Export.image  1_8   COMPLETED  ---
# CKW7NRLDAVXA5JC2TEGPW7IH  Export.image  1_7   COMPLETED  ---
# VB5ZOIAUQTOPC64MYDVVFS63  Export.image  1_6   COMPLETED  ---
# ZAOMJMBAVUIJIO3MQXIO6OIX  Export.image  1_5   COMPLETED  ---
# EXO7YJZJE236YFJSLZOE253L  Export.image  1_4   COMPLETED  ---
# ZUCJ6ZPI44O76EMKR3VKR76C  Export.image  1_3   COMPLETED  ---
# VXTY3F6HMYBVYB762KRIDJOC  Export.image  1_2   COMPLETED  ---
# Z4SGHENQI2RQFXOZ4OMZSR4U  Export.image  1_1   COMPLETED  ---
# BEJ4E7WURMEW62KI5ULNTQBL  Export.image  1_0   COMPLETED  ---
# 2AUZ2HAGTKJVSLJIP2BOO6WH  Export.image  1_30  COMPLETED  ---
# MOZ2VFGE2PNC5UO2BIWDYNNY  Export.image  1_29  COMPLETED  ---
# RA54QWZC73BMWVNA4EGUCRZX  Export.image  1_27  COMPLETED  ---
# ZDPI74P3ASX7333J3ZIKX3VS  Export.image  1_26  COMPLETED  ---
# Z6D6VQ3YCTX23LTF75N2TA4K  Export.image  1_25  COMPLETED  ---
# 5HOAFEQNIUVDYKOZQPU3DMHW  Export.image  1_24  COMPLETED  ---
# SBUKDTLSJD4YM2XPWDE32KDY  Export.image  1_23  COMPLETED  ---
# UNHW5E2KZKZZR7M3CXUHDG5C  Export.image  1_22  COMPLETED  ---
# 4GGVY7T2AFXJ2SB27W6V4IJM  Export.image  1_21  COMPLETED  ---
# VMNYQJ2D2F4VWCF7ZUU5M2KY  Export.image  1_20  COMPLETED  ---
# KVCNBO2KS6VXXFFMGSECASQU  Export.image  1_19  COMPLETED  ---
# J6V2APIWQ2OU72FF5MN46XSF  Export.image  1_17  COMPLETED  ---
# VONRCB62F3GVMSSUGABLOI2C  Export.image  1_16  COMPLETED  ---
# OC5BRSL5DZJBJVHKDWITYOK2  Export.image  1_15  COMPLETED  ---
# SW2Y7TGFFLZEUFTCW6BJN2JX  Export.image  1_14  COMPLETED  ---
# ZK46NXYI2524YQKIOK2DC6JV  Export.image  1_13  COMPLETED  ---
# 7FHMT5X4NHNNHORRMRB52I5M  Export.image  1_12  COMPLETED  ---
# VN2T6I3B47DOFMTEUQ36ULR4  Export.image  1_11  COMPLETED  ---
# RFL3A26KDJTKRY4KKKIRICUC  Export.image  1_10  COMPLETED  ---
# ZPIWNI646T75YTLC7Q263OKD  Export.image  1_9   COMPLETED  ---
# 4I7WGXVGGBBBNPYDZQB3K7F2  Export.image  1_8   COMPLETED  ---
# YYKJ4GCKTJX7UXSX7KDQHMGG  Export.image  1_7   COMPLETED  ---
# GMHP6LAJE4ALDY3NFFEOXHPZ  Export.image  1_6   COMPLETED  ---
# GD7VUTQV4HQVSM2S7DSHA46G  Export.image  1_5   COMPLETED  ---
# PQTR7G5ZRJAX3GCXMMAI6E3C  Export.image  1_4   COMPLETED  ---
# BNSLN73WCLQV3FTCIHK5RZ3O  Export.image  1_3   COMPLETED  ---
# TL6P2B32L6NTBAPQS4XECZGY  Export.image  1_2   COMPLETED  ---
# LORF4G64VQUQDXFJR2QLEPA6  Export.image  1_1   COMPLETED  ---
# BJLYGHPGSPAXJMBDUZADDP5J  Export.image  1_0   COMPLETED  ---
# UBXTJEBMMS52WAEGSY7YTXGF  Export.image  1_30  COMPLETED  ---
# KCNDGSUE76VSCJNO4U3QET35  Export.image  1_29  COMPLETED  ---
# SGLJ4ZI6UIDLPGYK6L4TG3HZ  Export.image  1_27  COMPLETED  ---
# N56M6U3BSZJJJQA67XKBDDJD  Export.image  1_26  COMPLETED  ---
# O2TSAUAYC6ERENUFETCQAQ5L  Export.image  1_25  COMPLETED  ---
# 2DUW3EQICUB5WFSSU2J2N2DR  Export.image  1_24  COMPLETED  ---
# POSMSMQMJJTK4OAJBDLCUNVK  Export.image  1_23  COMPLETED  ---
# BUD6W3KKYKBD42VXFFN7EWNQ  Export.image  1_22  COMPLETED  ---
# TJWA5OGOJYVZVBFOYWAWIUAF  Export.image  1_21  COMPLETED  ---
# YQVUWOX5PYZLJOAZX6IKTTZL  Export.image  1_20  COMPLETED  ---
# UJCVY7XED324BGC5KWDBB2YJ  Export.image  1_19  COMPLETED  ---
# LDXLUNITKIXKAKLLG4ISNFHC  Export.image  1_17  COMPLETED  ---
# CQXGSRJ7RLDNGJ4UAOOWFTC4  Export.image  1_16  COMPLETED  ---
# M4GAVESTWPQUN3PBNBD5U7QE  Export.image  1_15  COMPLETED  ---
# ZPI2QVDKW3JG7KNO2RKRH5ZI  Export.image  1_14  COMPLETED  ---
# 4ZUS3HIZ7PE6IRE3GEE6M2SF  Export.image  1_13  COMPLETED  ---
# PWO7O4Q3NJIY2KJKSHNBSGSK  Export.image  1_12  COMPLETED  ---
# XP5KZPCMSKNTGYFVLRDZK7GU  Export.image  1_11  COMPLETED  ---
# K7TVU5UQ3GA7GKETRGHVWQKA  Export.image  1_10  COMPLETED  ---
# 6V2TEI6IYLSM2DH6NVO3XZB6  Export.image  1_9   COMPLETED  ---
# EIXZUIQ4NPOGKASLQ6FLCTFK  Export.image  1_8   COMPLETED  ---
# DS53234Z3QQ3MLIM6ER7M4D2  Export.image  1_7   COMPLETED  ---
# JY4YSJRVP4X7TDTM4D23W7CR  Export.image  1_6   COMPLETED  ---
# 5X6VISQVBNFNS4PYO77YTRFX  Export.image  1_5   COMPLETED  ---
# 5FD4PJDYD7KU7ZT4VXEJLEZX  Export.image  1_4   COMPLETED  ---
# XR2RAI6JKXTF7RRS5PD3GRF6  Export.image  1_3   COMPLETED  ---
# LDMZJX5ON65ZBNC3LTJATJOR  Export.image  1_2   COMPLETED  ---
# BHDPIY74HH74HUM5P5CW2XB4  Export.image  1_1   COMPLETED  ---
# IRD5Q5HHPA2PFCNYR4GN2YMK  Export.image  1_0   COMPLETED  ---
# FUMCJSN5JBSE4XWY3VJGZ4K6  Export.image  1_30  COMPLETED  ---
# GA2OCBYOXFVNBSEIHOKJ22JU  Export.image  1_29  COMPLETED  ---
# B36AFCDWUBW2ZUJ3IQ3WWFDG  Export.image  1_27  COMPLETED  ---
# 4HG7I6KHL2NJ7CAWRBMVNSQH  Export.image  1_26  COMPLETED  ---
# F3WBI4A2MGDDQTBER4JGJZYS  Export.image  1_25  COMPLETED  ---
# 4BXOQACEEG2XLSKWCHXACXEH  Export.image  1_24  COMPLETED  ---
# SHJ37Z76UI424XRAEQBMZYIX  Export.image  1_23  COMPLETED  ---
# PWCDKBZ2BUOJQCIJXWBJC5E5  Export.image  1_22  COMPLETED  ---
# CIZFMKJJBYM5OWVIER6T632K  Export.image  1_21  COMPLETED  ---
# TSVDBZFBXDKRYGAYVP3QS3SC  Export.image  1_20  COMPLETED  ---
# S6L7VYP5O3GBMB4TO5BCN37C  Export.image  1_19  COMPLETED  ---
# S5QMD7K5D5NHCANDNON4C72K  Export.image  1_17  COMPLETED  ---
# W7TM3CTT4M5LZCCDCP62QYAV  Export.image  1_16  COMPLETED  ---
# YBQT67WMKORRYFZO4BQ5KPEI  Export.image  1_15  COMPLETED  ---
# JJU55NQM23YWQ5UVEZ3Q3NXD  Export.image  1_14  COMPLETED  ---
# SQA7N6HCKIE6M2XQVNDZ43WF  Export.image  1_13  COMPLETED  ---
# RSJWRPVLEOPLDY4G7HV7DS3D  Export.image  1_12  COMPLETED  ---
# CEVISZOG4KP6CPLXQW4OQ2MG  Export.image  1_11  COMPLETED  ---
# ENDP73IJUYB3K46DQJHFXJC2  Export.image  1_10  COMPLETED  ---
# URDVPWZWJP2Q3GUOJY5PCUPW  Export.image  1_9   COMPLETED  ---
# 4JNSVOD7E2GIV5MPTGXKMBRM  Export.image  1_8   COMPLETED  ---
# YT7CQOQHPCKCAD5XUDGIBMZX  Export.image  1_7   COMPLETED  ---
# 3RGB252IHCXEPB3HUM2SN6T7  Export.image  1_6   COMPLETED  ---
# NBEW4BCN7PCXTSY5LACYP4GU  Export.image  1_5   COMPLETED  ---
# D523WWE67LLNTUTNDF45XDZK  Export.image  1_4   COMPLETED  ---
# L5HLJEQ22XKHA3LHCLLRVRCV  Export.image  1_3   COMPLETED  ---
# 56XJEH44CM4OPWUOTIEVK256  Export.image  1_2   COMPLETED  ---
# IAKZSVFTBHMWUUVX62VMLVG5  Export.image  1_1   COMPLETED  ---
# 3ONFYR7K54MSHDM3GECZBQKN  Export.image  1_0   COMPLETED  ---
# N4VL6KF2J2IGCDTFAJ2BOTOW  Export.image  1_30  COMPLETED  ---
# J2XQN4T5DHJW527YWWF226RB  Export.image  1_29  COMPLETED  ---
# UBMKMOTBFNCSO5JCJUC7DKQ6  Export.image  1_27  COMPLETED  ---
# KVXT2WPNFNNF63DX6GQ5KENU  Export.image  1_26  COMPLETED  ---
# MQ2BPZ63MZGBLHI6GRTI4FMR  Export.image  1_25  COMPLETED  ---
# REJJK33GXJS4KQJC232C3GSI  Export.image  1_24  COMPLETED  ---
# APHEOGYSDPJIYLUBS6HVQAQR  Export.image  1_23  COMPLETED  ---
# LPLCP4PPPZOFZJGWAU5NMMWH  Export.image  1_22  COMPLETED  ---
# J7GVY7ZZKTXVGGDTT2YDFXWN  Export.image  1_21  COMPLETED  ---
# TABOJME26FSF2EHF3ZAN5HOZ  Export.image  1_20  COMPLETED  ---
# 2QS65KEEJTKNIEIUP7J3O5XW  Export.image  1_19  COMPLETED  ---
# VCSL5PGGMNNW4A5WPRTF5YW5  Export.image  1_17  COMPLETED  ---
# JVHDWOUAKFAO7T3XB5IDJPR3  Export.image  1_16  COMPLETED  ---
# FQSXZWEOMRTVNHTEJ52VMIP5  Export.image  1_15  COMPLETED  ---
# PTHJO67PFUZTF2PCEQMTAAB7  Export.image  1_14  COMPLETED  ---
# NFM462JCB3GPLK5SGIMYCSBF  Export.image  1_13  COMPLETED  ---
# EXHQZXHGHNPNTNFW52DYC5PW  Export.image  1_12  COMPLETED  ---
# TTR6BTJW2NEUGTHUMHTWSO3R  Export.image  1_11  COMPLETED  ---
# QSY3VR45FVZPL7L62P6JOF6E  Export.image  1_10  COMPLETED  ---
# CK6PQNAVMT6K32MJYTTI6KSB  Export.image  1_9   COMPLETED  ---
# 3LZYZ5A6D6PEQNDFWLPDNU6T  Export.image  1_8   COMPLETED  ---
# XZGVB4GLK7YWXRKUJGRT724S  Export.image  1_7   COMPLETED  ---
# G7G5K7YUGAOW5VC6YPAW2NH4  Export.image  1_6   COMPLETED  ---
# ZSKG6NCWMRK4FYQJKTJV46A5  Export.image  1_5   COMPLETED  ---
# MJOXBEJL7NXBKNK7NGTP45NY  Export.image  1_4   COMPLETED  ---
# VVSSZGQALCZJFT7THIW4ZURL  Export.image  1_3   COMPLETED  ---
# JPNLXVIGQJ6ADB6LDD3U5KKE  Export.image  1_2   COMPLETED  ---
# V3MA2OZBKUFNRHO5NF6KZXJ6  Export.image  1_1   COMPLETED  ---
# XPXO2LG2FTJOWF7WBUMOQTSF  Export.image  1_0   COMPLETED  ---
# KIF5RJCXCG2GF25MIZ37AAOR  Export.image  1_30  COMPLETED  ---
# CQ63PH7INDGA6SAZEHB5LXRJ  Export.image  1_29  COMPLETED  ---
# AIMKFND3ISCD6VCI6LLCTS3B  Export.image  1_27  COMPLETED  ---
# ZXJP4UPUCSLPC7DMLAB4KQUG  Export.image  1_26  COMPLETED  ---
# S3MN46DR27LN2JF4NUQBS5H4  Export.image  1_25  COMPLETED  ---
# VCKSYJL6LSUNT7QUUVVX4WFX  Export.image  1_24  COMPLETED  ---
# OQIIOPX42LX5DGKBROPCQASP  Export.image  1_23  COMPLETED  ---
# LPVTKIUIKL2J37JKMQYCX6GI  Export.image  1_22  COMPLETED  ---
# 2TGEX6ROH4YMQSRBNB733S7O  Export.image  1_21  COMPLETED  ---
# RLKHHJ33ABDJAMCPPN353W2K  Export.image  1_20  COMPLETED  ---
# YC64MPWZYVVPHCBJIIEZR3E5  Export.image  1_19  COMPLETED  ---
# T7BQT5NLGXDKNEXHUCNWDOZQ  Export.image  1_17  COMPLETED  ---
# WOA6J7FUETPZ34NTOKYZ5KZO  Export.image  1_16  COMPLETED  ---
# A7EAYIKPPOQGMOC4PTYPWLZM  Export.image  1_15  COMPLETED  ---
# U7QYHA7UZ4G4D4A7FRCF6GU3  Export.image  1_14  COMPLETED  ---
# 42UPAKHWRL3GDSAV4I65GGHD  Export.image  1_13  COMPLETED  ---
# EXFHNXTXZTQ2H3OS2QV6BOBH  Export.image  1_12  COMPLETED  ---
# CHOQLT6XOCJXQW7IIKMCXSOT  Export.image  1_11  COMPLETED  ---
# DH3ZJUQBBV5RD2VOWAZIZEIY  Export.image  1_10  COMPLETED  ---
# QLKQN7EZ6TK6XA6PTUHAWCWH  Export.image  1_9   COMPLETED  ---
# 6W76YNRINIBYRUEGDWDOW37V  Export.image  1_8   COMPLETED  ---
# LI5T5SELKBUUJ7UGNL6SXVMK  Export.image  1_7   COMPLETED  ---
# HECOU7EJYJV3F6VEKTU67ZZU  Export.image  1_6   COMPLETED  ---
# BNIPOB2UY4UXNFKDD2CMRZDU  Export.image  1_5   COMPLETED  ---
# GUZH7VBJ5RGPX7QYNGCESUPZ  Export.image  1_4   COMPLETED  ---
# 2OJ23XVMZRTB6IMMWIBK7LJY  Export.image  1_3   COMPLETED  ---
# C4PJXFANFILIEN6LYJT52A5D  Export.image  1_2   COMPLETED  ---
# 5THORXQJS7FRD5XA6F7RIHD6  Export.image  1_1   COMPLETED  ---
# 6CO4BWUEXMG3EPRSSVWH4JNT  Export.image  1_0   COMPLETED  ---
# PXJMOV7YVGMHFPZUTGNR35QD  Export.image  1_30  COMPLETED  ---
# MNXPW7VDDDH3BPV5RPGMMSKO  Export.image  1_29  COMPLETED  ---
# NURU7K7AISMBNPDZMDXPGJWN  Export.image  1_27  COMPLETED  ---
# JGTAATALA2VG5FAVDE5ROYEP  Export.image  1_26  COMPLETED  ---
# ASQD7G5X5R6KZMA3QSLBRB2H  Export.image  1_25  COMPLETED  ---
# SMRNEO2HAJUW4M7SWRMIK3AO  Export.image  1_24  COMPLETED  ---
# LYPWF7WBPL7QK3DJVF762J7R  Export.image  1_23  COMPLETED  ---
# C2UUPDKQ6F6JKVXGPJNPDT53  Export.image  1_22  COMPLETED  ---
# C4VLKCZWOVJV32I2B5KIRKB7  Export.image  1_21  COMPLETED  ---
# WW4ADQCBGU2SRWD5YCYNS7Q7  Export.image  1_20  COMPLETED  ---
# ECBSMZ3GFDEQ5RMFHEQWTQBS  Export.image  1_19  COMPLETED  ---
# GPKRKZWWEDAJVTOCHA7BUEM4  Export.image  1_17  COMPLETED  ---
# J7G45XEI62HVHKVBB2ODAWOV  Export.image  1_16  COMPLETED  ---
# M47YW6A75D637DALD2XVFKKV  Export.image  1_15  COMPLETED  ---
# ITAYKF7C7Z7WM3257F362RW2  Export.image  1_14  COMPLETED  ---
# JEIFMG3BN3QYAAQQSSKYV72F  Export.image  1_13  COMPLETED  ---
# CXVLDXZXGUU7BQOJTTDXIR4D  Export.image  1_12  COMPLETED  ---
# VLGTMC2BLHXDXA76XNPNP47Q  Export.image  1_11  COMPLETED  ---
# N7U6RQBWEHLWD36E4E5OMZBZ  Export.image  1_10  COMPLETED  ---
# FBB22FRNLLSLMTZ6IS2QO6IS  Export.image  1_9   COMPLETED  ---
# Q7EJBHLTWKQLKQFHVRHTV2J4  Export.image  1_8   COMPLETED  ---
# TJLU5HXXOYMGK27Q3IRZWOHA  Export.image  1_7   COMPLETED  ---
# XI6SU6BPGKQHTNGJ3EPR6UVC  Export.image  1_6   COMPLETED  ---
# OXWALB6JG4NLQXPFAT2WZUQP  Export.image  1_5   COMPLETED  ---
# NXEH6QQJG44OYHIHTT7RHEB4  Export.image  1_4   COMPLETED  ---
# 4YKOCWKE4V7FPRLXLM2KB5SU  Export.image  1_3   COMPLETED  ---
# 3U3XJ23WXB6U2TZA3KNPVIF6  Export.image  1_2   COMPLETED  ---
# ZVTKWRLKCUMKAQ6RQB2CCCMH  Export.image  1_1   COMPLETED  ---
# A6SD3FF3KRQ4BI6WPP2E6O2Q  Export.image  1_0   COMPLETED  ---
# DRPX4IVZ5GDS7AAINERMCR4R  Export.image  1_30  COMPLETED  ---
# C4DOGG2Q4CKXVFMFY26QIWLR  Export.image  1_29  COMPLETED  ---
# 77342GIHSS2YIBQRMFKHNOES  Export.image  1_27  COMPLETED  ---
# D3ZQGXXXMKCU6IKE2J5BKRGM  Export.image  1_26  COMPLETED  ---
# LQGYJ55EIC6F4GUK3K77356A  Export.image  1_25  COMPLETED  ---
# VZB5XOMMIXYNU3Z6TQLFYSNK  Export.image  1_24  COMPLETED  ---
# 55ZA7AVLABEPG3VTSOFXR66R  Export.image  1_23  COMPLETED  ---
# XHDEFYD3VFJO2RAIRUOY7MNF  Export.image  1_22  COMPLETED  ---
# NZCC5IOWVH46CMQFIEN7K3RA  Export.image  1_21  COMPLETED  ---
# RDCUQVZMF5EOA5CVSZZE6KHR  Export.image  1_20  COMPLETED  ---
# N62N5DV54CKBZAFUBFYLURO2  Export.image  1_19  COMPLETED  ---
# XYAYCNM73RIRRDCTZQE37IAU  Export.image  1_17  COMPLETED  ---
# DLOGVI6LID4K3MB6OBPIFIEY  Export.image  1_16  COMPLETED  ---
# UPQAUZZHNMJJZTKDARSVUROM  Export.image  1_15  COMPLETED  ---
# 3WKX2Y36GYQ5LBCO7IXYHVVQ  Export.image  1_14  COMPLETED  ---
# RIZEBNESKGWUDSA5XD2SMI7Z  Export.image  1_13  COMPLETED  ---
# 3URSGVFW2C6D2PXPVIFGI43S  Export.image  1_12  COMPLETED  ---
# FSQ5IID6R7CWRDUGCPIXL3XK  Export.image  1_11  COMPLETED  ---
# QL3AKFPLAMYU754WW44Y5DUH  Export.image  1_10  COMPLETED  ---
# OJFAFV5CF3M22LLTYVJE3WR5  Export.image  1_9   COMPLETED  ---
# GMWTIJILETHYP6Z36HKRISKI  Export.image  1_8   COMPLETED  ---
# 5GVBCT5GOZQPLNQZCLGVNVZO  Export.image  1_7   COMPLETED  ---
# 5MIN7A3GYXVE644UMDBYT7TN  Export.image  1_6   COMPLETED  ---
# DVCWLF23CD26UVX7NSF7MWN4  Export.image  1_5   COMPLETED  ---
# TOBEJF2OBSKVJNOCBRFD4A7R  Export.image  1_4   COMPLETED  ---
# AQNVQHPXVKCCAPZDVUAL7JCF  Export.image  1_3   COMPLETED  ---
# LIZGBKQ35EGJWONZYRQA63CM  Export.image  1_2   COMPLETED  ---
# IYMUJ3OG3R5M7IJCOO4UR6PG  Export.image  1_1   COMPLETED  ---
# 6H6WNPDZDWVZBDW7ALFSY5HO  Export.image  1_0   COMPLETED  ---
# 5NR5WC76S5EXRAPL55WQW67V  Export.image  1_1   COMPLETED  ---
# T7EMMYXXYCY3MQP2KG7LYTWP  Export.image  1_0   COMPLETED  ---
# EGKTVLDD47QEH4LVDGGJI5B3  Export.image  1_3   CANCELLED  Cancelled.
# 4IZXAWVNK6HOZPMY6L35LEVC  Export.image  1_2   CANCELLED  Cancelled.
# WJQY4OYC745BUZ4SFP4IGAJI  Export.image  1_1   CANCELLED  Cancelled.
# 44DOZCK35ZSFLIAZJARZN74L  Export.image  1_0   CANCELLED  Cancelled.
# L4UKCKNGVFNYUQ5D2GAYSYNN  Export.image  1_6   CANCELLED  Cancelled.
# PUBEKBZYWYYQM36M6Z3MYZ6C  Export.image  1_5   CANCELLED  Cancelled.
# TPW6TQZEG2L5CWUCUC7TZS3K  Export.image  1_4   CANCELLED  Cancelled.
# TYNNHLPTLQ7TF52PEL73SVBC  Export.image  1_3   COMPLETED  ---
# SXZTBSOK7IJN3DCM6E77SJRP  Export.image  1_2   COMPLETED  ---
# FK6RORSS2AC5JIA5SQBPHJUP  Export.image  1_1   COMPLETED  ---
# HZA6XDSAA7HJF4Y67IVDFP56  Export.image  1_0   COMPLETED  ---
# 2I4VFMQ2KX3NWM5MMXHTAGBS  Export.image  1_9   CANCELLED  Cancelled.
# Q7DWIIVVQB2QA6C46VZYFRDA  Export.image  1_8   CANCELLED  Cancelled.
# JISF4MDRGLDISM543OG4HICR  Export.image  1_7   CANCELLED  Cancelled.
# SY733WWD6UUJSA7FN3G6NODY  Export.image  1_6   CANCELLED  Cancelled.
# ORVCXNX6O52GOMRHOUTQCANP  Export.image  1_5   CANCELLED  Cancelled.
# D26OG2EN6RCZPBUDUQEL2UYF  Export.image  1_4   CANCELLED  Cancelled.
# V7HYHDUOUMYGF3XCYQEC2XSC  Export.image  1_3   COMPLETED  ---
# GV3MW54D323XVXAOH7F4VM2E  Export.image  1_2   COMPLETED  ---
# KGV4A7DPUP67V3ZSC5SBTATK  Export.image  1_1   CANCELLED  Cancelled.
# BV3PH6VZVUSAHFYHKWSJW4KC  Export.image  1_0   COMPLETED  ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5f6909edc642> in <module>
#       1 get_ipython().system('earthengine task list')
#       2
# ----> 3 fn
#       4 get_ipython().system('earthengine authenticate')
#
# NameError: name 'fn' is not defined

# %%
fin

# %%
# fin

import folium
import ee
import ssl
import time
from pathlib import Path
import numpy as np
from shapely import wkt
import shapely

ee.Initialize()

import ee
import ssl
import time
from pathlib import Path
import numpy as np
import shapely
from shapely import wkt
import os

from .utils import load_clean_yield_data as load
from .utils import get_tif_files
from .. import MAJOR_STATES

# %%
# fin

import folium
import ee
import ssl
import time
from pathlib import Path
import numpy as np
from shapely import wkt
import shapely

ee.Initialize()

def _export_one_image(img, folder, name, region, scale, crs):
    # export one image from Earth Engine to Google Drive
    # Author: Jiaxuan You, https://github.com/JiaxuanYou
    print(f"Exporting _exp to {folder}/{name}")
    cwd = os.getcwd()
    print('cwd : ', cwd)
    print('folder : ', folder)
    # print('_exp img : ', type(img))
    # print('_exp region : ', type(region))
    # print('_exp img : ', type(img), img.getInfo())
    # folder = "/content/gdrive/My Drive/AYield/China/pycrop-yield-prediction/data/crop_yield-data_image"
    task_dict = {
        "driveFolder": folder,
        "driveFileNamePrefix": name,
        "scale": scale,
        "crs": crs,
    }
    if region is not None:
        task_dict.update({"region": region})
    task = ee.batch.Export.image(img, name, task_dict)
    task.start()
    while task.status()["state"] == "RUNNING":
        print("Running...")
        # Perhaps task.cancel() at some point.
        time.sleep(10)
    # print('_exp img : ', type(img), img.getInfo())
    # print('_exp region : ', type(region))
    print(f"Done: {task.status()}")

def _append_mask_band(current, previous):
    # Transforms an Image Collection with 1 band per Image into a single Image with items as bands
    # Author: Jamie Vleeshouwer

    # Rename the band
    previous = ee.Image(previous)
    current = current.select([0])
    # Append it to the result (Note: only return current item on first element/iteration)
    return ee.Algorithms.If(
        ee.Algorithms.IsEqual(previous, None),
        current,
        previous.addBands(ee.Image(current)),
    )


def _append_temp_band(current, previous):
    # Transforms an Image Collection with 1 band per Image into a single Image with items as bands
    # Author: Jamie Vleeshouwer

    # Rename the band
    previous = ee.Image(previous)
    current = current.select([0, 4])
    # Append it to the result (Note: only return current item on first element/iteration)
    return ee.Algorithms.If(
        ee.Algorithms.IsEqual(previous, None),
        current,
        previous.addBands(ee.Image(current)),
    )


def _append_im_band(current, previous):
    # Transforms an Image Collection with 1 band per Image into a single Image with items as bands
    # Author: Jamie Vleeshouwer

    # Rename the band
    previous = ee.Image(previous)
    current = current.select([0, 1, 2, 3, 4, 5, 6])
    # Append it to the result (Note: only return current item on first element/iteration)
    return ee.Algorithms.If(
        ee.Algorithms.IsEqual(previous, None),
        current,
        previous.addBands(ee.Image(current)),
    )


collection_id='MODIS/006/MOD09A1'

imgcoll = (
    ee.ImageCollection(collection_id)
    .filterBounds(ee.Geometry.Rectangle(70, 54, 135, 17))
    .filterDate("2002-12-31", "2005-8-4")
    )

datatype_to_func = {
    "image": _append_im_band,
    "mask": _append_mask_band,
    "temperature": _append_temp_band,
    }

data_type = 'image'

img = imgcoll.iterate(datatype_to_func[data_type])
img = ee.Image(img)

def add_ee_layer(self, ee_image_object, vis_params, name):
  map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
  folium.raster_layers.TileLayer(
      tiles=map_id_dict['tile_fetcher'].url_format,
      attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
      name=name,
      overlay=True,
      control=True
  ).add_to(self)

folium.Map.add_ee_layer = add_ee_layer

# Load an image.
# image = ee.Image('LANDSAT/LC08/C02/T1_TOA/LC08_044034_20140318')
# !pwd
# !ls
import sys
from cyp.data.utils import load_clean_yield_data as load
locations_filepath=Path("data/china_yield/wheat_2002-2018.csv")
locations = load(locations_filepath)

# print(type(locations))
# locations.head(5)
# sys.exit(0)
# fn

################################################################################
features=[]
for index, row in locations.iterrows():
    # polyg = i.geometry
    # print(type(row), row['geometry'])
    polyg = wkt.loads(row['geometry'])
    # print('polyg : ', index, type(polyg), polyg)
    polyg_gson = [{'type': 'Feature', 'properties': {}, 'geometry': shapely.geometry.mapping(polyg)}]
    # print(type(polyg_gson[0]['geometry']['coordinates']), list(polyg_gson[0]['geometry']['coordinates'][0]))
    tuples = list(polyg_gson[0]['geometry']['coordinates'][0])
    polyg_lists = [list(x) for x in tuples]
    # print(type(polyg_lists), polyg_lists)
    g=ee.Geometry.Polygon(polyg_lists) 
    # print('GEE 1: ', type(g), g.getInfo())
    # print('GEE 2: ', type(g), g.getInfo()['coordinates'])
    feature = ee.Feature(g, {'County ANSI':ee.String(str(row['County ANSI'])), 'State ANSI':ee.String(str(row['State ANSI']))})
    # print('Features 1: ', type(feature), feature.getInfo())
    # print('Features 2: ', feature)
    features.append(feature)
    # fin
print("Feature collection done")               
region = ee.FeatureCollection(features)
print('region : ', type(region))
# print('region : ', type(region), region.getInfo())
# fin
###############################################################################

for state_id, county_id in np.unique(
    locations[["State ANSI", "County ANSI"]].values, axis=0
):
    # if major_states_only:
    #     if int(state_id) not in MAJOR_STATES:
    #         print(f"Skipping state id {int(state_id)}")
    #         continue

    fname = "{}_{}".format(int(state_id), int(county_id))
    print('fname : ', fname)

    file_region = region.filterMetadata(
        "County ANSI", "equals", str(county_id)
    ).filterMetadata("State ANSI", "equals", str(state_id))
    # print('fr: ', type(file_region), type(file_region.first()))
    # print('fr: ', type(file_region), type(file_region.geometry().getInfo()))
    # # print('fr: ', type(file_region), file_region.geometry().getInfo())
    # print('fr: ', type(file_region), file_region.geometry().getInfo()['coordinates'])
    # file_region = ee.Feature(file_region)

    # processed_img = image.clip(file_region)
    # print(type(image), type(processed_img))

    file_region = ee.Feature(file_region.first())
    processed_img = img.clip(file_region)
    # print('processed_img.getInfo() : ', processed_img.getInfo())

    # Define the visualization parameters.
    image_viz_params = {
        # 'bands': ['B5', 'B4', 'B3'],
        'bands': ['sur_refl_b05', 'sur_refl_b04', 'sur_refl_b03'], 
        # 'min': 0,
        # 'max': 0.5,
        # 'gamma': [0.95, 1.1, 1]
    }

    coordinate_system="EPSG:4326",
    scale=500

    file_region = None
    while True:
        try:
          _export_one_image(
                processed_img,
                # download_folder,
                "/content/gdrive/My Drive/AYield/China/pycrop-yield-prediction/data/crop_yield-data_image",
                fname,
                file_region,
                scale,
                coordinate_system,
            )
        except ee.ee_exception.EEException as e:
          print(str(e))
        except ssl.SSLEOFError as e:
          print(str(e))
        # except (ee.ee_exception.EEException, ssl.SSLEOFError):
        #     print(f"Retrying State {int(state_id)}, County {int(county_id)}")
        #     print(ee.ee_exception.EEException)
        #     print(ssl.SSLEOFError)
        #     time.sleep(10)
          break
          continue
        break

    # fin



    # Define a map centered on San Francisco Bay.
    map_l8 = folium.Map(location=[35, 100], zoom_start=10)

    # Add the image layer to the map and display it.
    map_l8.add_ee_layer(processed_img, image_viz_params, 'false color composite')
    display(map_l8)
    sys.exit(0)

# %%
locations.head(5)

# %%
# !python run.py process
# !python run.py export

# %%
# fn
# !earthengine authenticate
