# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# !ls
# Out:
# Mounted at /content/gdrive/
# gdrive	sample_data

# %%
import os

home_dir = '/content/gdrive/My Drive/AChina'
os.chdir(home_dir)
# !pwd
# !ls
# !pip3 install --upgrade IPython
# !pip install fire
# !pip install geopandas
# !pip install geojson
# !pip install tqdm

from tqdm import tqdm
import geojson

from glob import glob

# sudo apt-get update & apt-get upgrade

# !pip install --upgrade google-api-python-client
# !gcloud init
# Out:
# /content/gdrive/My Drive/AChina
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 87 kB 3.4 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=0c468c28846cf21f59b3b7fa02d93fb257a292ac0e94ffc57551edb1fea8b367
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 49.6 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 58.5 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
code_dir = os.path.join(home_dir, 'china')
os.chdir(code_dir)
# !pwd
# !ls
# Out:
# /content/gdrive/My Drive/AChina/china
# AChina_Predict_visual.ipynb	    pycropparser.ipynb
# ChinaTransformer.ipynb		    pyield_engineer.ipynb
# CropAreaAugmentation.ipynb	    pyield_rnn2.ipynb
# CropArea_calc.ipynb		    pyield_rnn3.ipynb
# cyp				    pyield_rnn4.ipynb
# feature_Generator.ipynb		    pyield_rnn.ipynb
# Hist_analize.ipynb		    pyviewer2.ipynb
# Histo_csv_prl_to_Transformer.ipynb  pyviewer.ipynb
# Histo_csv_to_Transformer.ipynb	    rename_county.ipynb
# images_min_max.ipynb		    run.py
# MODIS_Downloader.ipynb		    task_file_generate.ipynb
# MODIS_Processing.ipynb		    TensorBoard.ipynb
# parse_county.ipynb		    Yield_csv_clearing.ipynb

# %%
# env = os.getenv(key='TCMALLOC_LARGE_ALLOC_REPORT_THRESHOLD')
env = os.environ
print(env)
os.environ['TCMALLOC_LARGE_ALLOC_REPORT_THRESHOLD'] = '8528003072'
print(os.environ['TCMALLOC_LARGE_ALLOC_REPORT_THRESHOLD'])
#  fn
# !earthengine authenticate
# !earthengine task cancel all
# Out:
# environ({'NV_LIBCUBLAS_DEV_VERSION': '11.4.1.1043-1', 'NV_CUDA_COMPAT_PACKAGE': 'cuda-compat-11-2', 'NV_CUDNN_PACKAGE_DEV': 'libcudnn8-dev=8.1.1.33-1+cuda11.2', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib:/usr/local/nvidia/lib64', 'NV_LIBNCCL_DEV_PACKAGE': 'libnccl-dev=2.8.4-1+cuda11.2', 'TCLLIBPATH': '/usr/share/tcltk/tcllib1.19', 'CLOUDSDK_PYTHON': 'python3', 'LANG': 'en_US.UTF-8', 'NV_LIBNPP_DEV_PACKAGE': 'libnpp-dev-11-2=11.3.2.152-1', 'HOSTNAME': 'a346d1f9f27e', 'OLDPWD': '/', 'CLOUDSDK_CONFIG': '/content/.config', 'KMP_EXTRA_ARGS': '--listen_host=172.28.0.2 --target_host=172.28.0.2 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-hm-2qnuo24l5knre --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true', 'NV_LIBNPP_VERSION': '11.3.2.152-1', 'NV_NVPROF_DEV_PACKAGE': 'cuda-nvprof-11-2=11.2.152-1', 'NVIDIA_VISIBLE_DEVICES': 'all
# ...

# %%
# fin
# !pwd
# !python run.py process
# !python run.py process
# Out:
# /content/gdrive/My Drive/AChina/china
# MODISProcessing TASK :
# {
#     "YIELD_DATA_PATH": "../wheat.csv",
#     "CLEAR_YIELD_DATA_PATH": "../wheat.csv",
#     "MASK_PATH": "../data/crop_yield-data_mask",
#     "TEMPERATURE_PATH": "../data/crop_yield-data_temperature",
#     "IMAGE_PATH": "../data/crop_yield-data_image",
#     "CLEANED_DATA_PATH": "../data/img_output",
#     "COUNTY_DATA_PATH": "../county_data.csv",
#     "MODELS_PATH": "../data/models",
#     "RANGE_DOWNLOAD": [
#         "2017-01-01",
#         "2018-12-31"
#     ],
#     "NUM_PROC_YEARS": 2
# }
# ./../data/crop_yield-data_image
# ../data/crop_yield-data_image
# start year :  <class 'int'> 2017
# ...

# %%
fn
# !earthengine authenticate
