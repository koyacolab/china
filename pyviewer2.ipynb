# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# !ls
# Out:
# Mounted at /content/gdrive/
# gdrive	sample_data

# %%
import os

home_dir = '/content/gdrive/My Drive/AYield/China'
os.chdir(home_dir)

# %%
from google.colab import files

# pth = os.path.join(home_dir, 'pycrop-yield-prediction/', 'run.py')    
# pth = os.path.join(home_dir, 'pycrop-yield-prediction/', 'run2.py')
# pth = os.path.join(home_dir, 'pycrop-yield-prediction/', 'run3.py')
# pth = os.path.join(home_dir, 'pycrop-yield-prediction/cyp/data', 'exporting.py')
# pth = os.path.join(home_dir, 'pycrop-yield-prediction/cyp/data', 'preprocessing.py')
# pth = os.path.join(home_dir, 'pycrop-yield-prediction/cyp/data', 'feature_engineering.py')
# pth = os.path.join(home_dir, 'pycrop-yield-prediction/cyp/data', 'feature_engineering2.py')        
# pth = os.path.join(home_dir, 'pycrop-yield-prediction/cyp/models', 'base.py')
# pth = os.path.join(home_dir, 'pycrop-yield-prediction/cyp/models', 'loss.py')
pth = os.path.join(home_dir, 'pycrop-yield-prediction/cyp/models', 'rnn.py')


print(pth)
files.view(pth)
# Out:
# /content/gdrive/My Drive/AYield/China/pycrop-yield-prediction/cyp/models/rnn.py
